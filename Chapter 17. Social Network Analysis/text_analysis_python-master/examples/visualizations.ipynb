# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Basic stats (number words, articles, words/articles...)

# %%
with open("./data/Pablo_Iglesias_Podemos.csv") as f:
    for line in f:
        date, newspaper, content = line.split("\t")
        number_words = len(content.split(" "))
        print("We have {0} words in date {1}".format(number_words,date))
# Out:
# We have 543 words in date December 16, 2015 Wednesday  2ª Ed. Barna Edición
# We have 543 words in date December 16, 2015 Wednesday  2ª Ed. Madrid Edición
# We have 296 words in date December 16, 2015 Wednesday  2ª Ed. Madrid Edición
# We have 543 words in date December 16, 2015 Wednesday  Nacional Edición
# We have 296 words in date December 16, 2015 Wednesday  Nacional Edición
# We have 716 words in date December 16, 2015 Wednesday  Comunidad Valenciana Edición
# We have 560 words in date December 17, 2015 Thursday  2ª Ed. Barna Edición
# We have 410 words in date December 17, 2015 Thursday  1ª Ed. Barna Edición
# We have 397 words in date December 17, 2015 Thursday  1ª Ed. Barna Edición
# We have 620 words in date December 17, 2015 Thursday  Andalucía Edición
# We have 94 words in date December 17, 2015 Thursday  Comunidad Valenciana Edición
# We have 627 words in date December 17, 2015 Thursday  Nacional Edición
# We have 93 words in date December 17, 2015 Thursday  Nacional Edición
# We have 560 words in date December 17, 2015 Thursday  2ª Ed. Barna Edición
# We have 410 words in date December 17, 2015 Thursday  1ª Ed. Barna Edición
# We have 397 words in date December 17, 2015 Thursday  1ª Ed. Barna Edición
# We have 620 words in date December 17, 2015 Thursday  Andalucía Edición
# We have 94 words in date December 17, 2015 Thursday  Comunidad Valenciana Edición
# We have 627 words in date December 17, 2015 Thursday  Nacional Edición
# We have 93 words in date December 17, 2015 Thursday  Nacional Edición
# We have 486 words in date December 19, 2015 Saturday  2ª Ed. Barna Edición
# We have 27 words in date December 19, 2015 Saturday  Andalucía Edición
# We have 486 words in date December 19, 2015 Saturday  2ª Ed. Barna Edición
# We have 27 words in date December 19, 2015 Saturday  Andalucía Edición
# We have 787 words in date December 20, 2015 Sunday  1ª Ed. Barna Edición
# We have 585 words in date December 20, 2015 Sunday  Andalucía Edición
# We have 130 words in date December 20, 2015 Sunday  Nacional Edición
# We have 119 words in date December 20, 2015 Sunday  Comunidad Valenciana Edición
# We have 787 words in date December 20, 2015 Sunday  1ª Ed. Barna Edición
# We have 585 words in date December 20, 2015 Sunday  Andalucía Edición
# We have 130 words in date December 20, 2015 Sunday  Nacional Edición
# We have 119 words in date December 20, 2015 Sunday  Comunidad Valenciana Edición
# We have 657 words in date December 21, 2015 Monday  1ª Ed. Barna Edición
# We have 164 words in date December 21, 2015 Monday  Nacional Edición
# We have 427 words in date December 21, 2015 Monday  Andalucía Edición
# We have 98 words in date December 21, 2015 Monday  Andalucía Edición
# We have 445 words in date December 21, 2015 Monday  Nacional Edición
# We have 657 words in date December 21, 2015 Monday  1ª Ed. Barna Edición
# We have 164 words in date December 21, 2015 Monday  Nacional Edición
# We have 427 words in date December 21, 2015 Monday  Andalucía Edición
# We have 98 words in date December 21, 2015 Monday  Andalucía Edición
# We have 445 words in date December 21, 2015 Monday  Nacional Edición
# We have 150 words in date December 22, 2015 Tuesday  2ª Ed. Barna Edición
# We have 424 words in date December 22, 2015 Tuesday  Nacional Edición
# We have 72 words in date December 12, 2015 Saturday  Comunidad Valenciana Edición
# We have 533 words in date December 12, 2015 Saturday  Nacional Edición
# We have 144 words in date December 12, 2015 Saturday  Nacional Edición
# We have 411 words in date December 13, 2015 Sunday  Comunidad Valenciana Edición
# We have 533 words in date December 13, 2015 Sunday  Nacional Edición
# We have 152 words in date December 13, 2015 Sunday  Nacional Edición
# We have 411 words in date December 13, 2015 Sunday  Comunidad Valenciana Edición
# We have 533 words in date December 13, 2015 Sunday  Nacional Edición
# We have 152 words in date December 13, 2015 Sunday  Nacional Edición
# We have 568 words in date December 14, 2015 Monday  Andalucía Edición
# We have 282 words in date December 14, 2015 Monday  Comunidad Valenciana Edición
# We have 616 words in date December 14, 2015 Monday  Nacional Edición
# We have 568 words in date December 14, 2015 Monday  Andalucía Edición
# We have 282 words in date December 14, 2015 Monday  Comunidad Valenciana Edición
# We have 616 words in date December 14, 2015 Monday  Nacional Edición
# We have 543 words in date December 16, 2015 Wednesday  2ª Ed. Barna Edición
# We have 543 words in date December 16, 2015 Wednesday  2ª Ed. Madrid Edición
# We have 296 words in date December 16, 2015 Wednesday  2ª Ed. Madrid Edición
# We have 543 words in date December 16, 2015 Wednesday  Nacional Edición
# We have 296 words in date December 16, 2015 Wednesday  Nacional Edición
# We have 716 words in date December 16, 2015 Wednesday  Comunidad Valenciana Edición

# %% [markdown]
# ## Counting words

# %%
with open("./data/Pablo_Iglesias_Podemos.csv") as f:
    for i,line in enumerate(f):
        date, newspaper, content = line.split("\t")
        number_words = len(content.split(" "))
        
        frequency_las = 100*content.count("la")/number_words
        frequency_els = 100*content.count("el")/number_words
        
        print("New article number {0}. la's: {1:3.2f}%. el's {2:3.2f}%".format(i,frequency_las,frequency_els))
# Out:
# New article number 0. la's: 6.26%. el's 6.45%
# New article number 1. la's: 6.26%. el's 6.45%
# New article number 2. la's: 9.80%. el's 7.09%
# New article number 3. la's: 6.26%. el's 6.45%
# New article number 4. la's: 9.80%. el's 7.09%
# New article number 5. la's: 7.12%. el's 6.56%
# New article number 6. la's: 5.36%. el's 4.46%
# New article number 7. la's: 10.00%. el's 5.37%
# New article number 8. la's: 8.82%. el's 6.55%
# New article number 9. la's: 5.48%. el's 5.00%
# New article number 10. la's: 6.38%. el's 6.38%
# New article number 11. la's: 5.42%. el's 5.10%
# New article number 12. la's: 6.45%. el's 5.38%
# New article number 13. la's: 5.36%. el's 4.46%
# New article number 14. la's: 10.00%. el's 5.37%
# New article number 15. la's: 8.82%. el's 6.55%
# New article number 16. la's: 5.48%. el's 5.00%
# New article number 17. la's: 6.38%. el's 6.38%
# New article number 18. la's: 5.42%. el's 5.10%
# New article number 19. la's: 6.45%. el's 5.38%
# New article number 20. la's: 7.00%. el's 4.12%
# New article number 21. la's: 3.70%. el's 0.00%
# New article number 22. la's: 7.00%. el's 4.12%
# New article number 23. la's: 3.70%. el's 0.00%
# New article number 24. la's: 6.73%. el's 5.59%
# New article number 25. la's: 8.89%. el's 8.03%
# New article number 26. la's: 11.54%. el's 10.00%
# New article number 27. la's: 5.88%. el's 4.20%
# New article number 28. la's: 6.73%. el's 5.59%
# New article number 29. la's: 8.89%. el's 8.03%
# New article number 30. la's: 11.54%. el's 10.00%
# New article number 31. la's: 5.88%. el's 4.20%
# New article number 32. la's: 7.91%. el's 7.15%
# New article number 33. la's: 3.05%. el's 4.27%
# New article number 34. la's: 7.26%. el's 5.39%
# New article number 35. la's: 4.08%. el's 4.08%
# New article number 36. la's: 8.31%. el's 4.04%
# New article number 37. la's: 7.91%. el's 7.15%
# New article number 38. la's: 3.05%. el's 4.27%
# New article number 39. la's: 7.26%. el's 5.39%
# New article number 40. la's: 4.08%. el's 4.08%
# New article number 41. la's: 8.31%. el's 4.04%
# New article number 42. la's: 6.67%. el's 6.00%
# New article number 43. la's: 5.66%. el's 6.13%
# New article number 44. la's: 6.00%. el's 6.00%
# New article number 45. la's: 6.67%. el's 6.00%
# New article number 46. la's: 5.66%. el's 6.13%
# New article number 47. la's: 6.00%. el's 6.00%
# New article number 48. la's: 4.82%. el's 12.05%
# New article number 49. la's: 8.80%. el's 4.13%
# New article number 50. la's: 7.78%. el's 7.50%
# New article number 51. la's: 4.82%. el's 12.05%
# New article number 52. la's: 8.80%. el's 4.13%
# New article number 53. la's: 7.78%. el's 7.50%
# New article number 54. la's: 7.86%. el's 7.14%
# New article number 55. la's: 5.93%. el's 4.24%
# New article number 56. la's: 7.69%. el's 6.99%
# New article number 57. la's: 5.21%. el's 6.88%
# New article number 58. la's: 3.71%. el's 2.39%
# New article number 59. la's: 7.86%. el's 7.14%
# New article number 60. la's: 5.93%. el's 4.24%
# New article number 61. la's: 7.69%. el's 6.99%
# New article number 62. la's: 5.21%. el's 6.88%
# New article number 63. la's: 3.71%. el's 2.39%
# New article number 64. la's: 6.07%. el's 1.85%
# New article number 65. la's: 6.07%. el's 1.85%
# New article number 66. la's: 6.35%. el's 2.65%
# New article number 67. la's: 6.35%. el's 2.65%
# New article number 68. la's: 6.35%. el's 2.65%
# New article number 69. la's: 6.35%. el's 2.65%
# New article number 70. la's: 5.71%. el's 3.49%
# New article number 71. la's: 5.71%. el's 3.49%
# New article number 72. la's: 4.32%. el's 4.86%
# New article number 73. la's: 4.32%. el's 4.86%
# New article number 74. la's: 7.37%. el's 4.21%
# New article number 75. la's: 7.37%. el's 4.21%
# New article number 76. la's: 7.52%. el's 4.81%
# New article number 77. la's: 6.02%. el's 9.02%
# New article number 78. la's: 6.02%. el's 9.02%
# New article number 79. la's: 5.88%. el's 6.25%
# New article number 80. la's: 7.52%. el's 4.81%
# New article number 81. la's: 6.02%. el's 9.02%
# New article number 82. la's: 6.02%. el's 9.02%
# New article number 83. la's: 5.88%. el's 6.25%
# New article number 84. la's: 6.31%. el's 5.19%
# New article number 85. la's: 6.31%. el's 5.19%
# New article number 86. la's: 6.82%. el's 9.09%
# New article number 87. la's: 7.14%. el's 9.52%
# New article number 88. la's: 6.82%. el's 9.09%
# New article number 89. la's: 7.14%. el's 9.52%
# New article number 90. la's: 5.60%. el's 7.07%
# New article number 91. la's: 4.27%. el's 7.93%
# New article number 92. la's: 4.27%. el's 7.93%
# New article number 93. la's: 4.50%. el's 2.70%
# New article number 94. la's: 5.60%. el's 7.22%
# New article number 95. la's: 4.27%. el's 7.93%
# New article number 96. la's: 8.32%. el's 5.03%
# New article number 97. la's: 5.60%. el's 7.07%
# New article number 98. la's: 4.27%. el's 7.93%
# New article number 99. la's: 4.27%. el's 7.93%
# New article number 100. la's: 4.50%. el's 2.70%
# New article number 101. la's: 5.60%. el's 7.22%
# New article number 102. la's: 4.27%. el's 7.93%
# New article number 103. la's: 8.32%. el's 5.03%
# New article number 104. la's: 6.78%. el's 4.88%
# New article number 105. la's: 10.17%. el's 2.54%
# New article number 106. la's: 6.78%. el's 4.88%
# New article number 107. la's: 10.17%. el's 2.54%
# New article number 108. la's: 8.20%. el's 4.92%
# New article number 109. la's: 10.24%. el's 5.51%
# New article number 110. la's: 8.14%. el's 5.34%
# New article number 111. la's: 8.35%. el's 5.49%
# New article number 112. la's: 8.20%. el's 4.92%
# New article number 113. la's: 10.24%. el's 5.51%
# New article number 114. la's: 8.20%. el's 4.92%
# New article number 115. la's: 10.24%. el's 5.51%
# New article number 116. la's: 8.14%. el's 5.34%
# New article number 117. la's: 8.35%. el's 5.49%
# New article number 118. la's: 8.20%. el's 4.92%
# New article number 119. la's: 10.24%. el's 5.51%
# New article number 120. la's: 11.49%. el's 7.72%
# New article number 121. la's: 11.76%. el's 7.61%
# New article number 122. la's: 11.49%. el's 7.72%
# New article number 123. la's: 11.76%. el's 7.61%
# New article number 124. la's: 6.63%. el's 9.39%
# New article number 125. la's: 6.63%. el's 9.39%
# New article number 126. la's: 8.02%. el's 5.90%
# New article number 127. la's: 8.02%. el's 5.90%
# New article number 128. la's: 8.28%. el's 6.71%
# New article number 129. la's: 8.28%. el's 6.71%
# New article number 130. la's: 8.09%. el's 4.89%
# New article number 131. la's: 8.09%. el's 4.89%
# New article number 132. la's: 7.29%. el's 5.87%
# New article number 133. la's: 8.01%. el's 7.21%
# New article number 134. la's: 7.29%. el's 5.87%
# New article number 135. la's: 8.01%. el's 7.21%
# New article number 136. la's: 7.29%. el's 5.87%
# New article number 137. la's: 8.01%. el's 7.21%
# New article number 138. la's: 7.29%. el's 5.87%
# New article number 139. la's: 8.01%. el's 7.21%
# New article number 140. la's: 5.27%. el's 6.12%
# New article number 141. la's: 5.26%. el's 6.11%
# New article number 142. la's: 5.27%. el's 6.12%
# New article number 143. la's: 5.26%. el's 6.11%
# New article number 144. la's: 5.70%. el's 7.28%
# New article number 145. la's: 5.70%. el's 7.28%
# New article number 146. la's: 6.34%. el's 5.45%
# New article number 147. la's: 6.34%. el's 5.45%
# New article number 148. la's: 4.84%. el's 9.68%
# New article number 149. la's: 4.84%. el's 9.68%
# New article number 150. la's: 4.84%. el's 9.68%
# New article number 151. la's: 4.84%. el's 9.68%
# New article number 152. la's: 5.97%. el's 5.81%
# New article number 153. la's: 5.97%. el's 5.81%
# New article number 154. la's: 6.19%. el's 6.46%
# New article number 155. la's: 6.19%. el's 6.46%
# New article number 156. la's: 6.97%. el's 6.23%
# New article number 157. la's: 7.41%. el's 7.16%
# New article number 158. la's: 6.97%. el's 6.23%
# New article number 159. la's: 7.41%. el's 7.16%
# New article number 160. la's: 7.75%. el's 4.25%
# New article number 161. la's: 7.75%. el's 4.25%
# New article number 162. la's: 5.60%. el's 4.37%
# New article number 163. la's: 7.25%. el's 6.19%
# New article number 164. la's: 5.45%. el's 4.50%
# New article number 165. la's: 7.61%. el's 6.30%
# New article number 166. la's: 7.25%. el's 6.19%
# New article number 167. la's: 5.60%. el's 4.37%
# New article number 168. la's: 7.25%. el's 6.19%
# New article number 169. la's: 5.45%. el's 4.50%
# New article number 170. la's: 7.61%. el's 6.30%
# New article number 171. la's: 7.25%. el's 6.19%
# New article number 172. la's: 6.84%. el's 5.96%
# New article number 173. la's: 6.84%. el's 5.96%
# New article number 174. la's: 6.15%. el's 4.52%
# New article number 175. la's: 6.29%. el's 4.68%
# New article number 176. la's: 6.15%. el's 4.52%
# New article number 177. la's: 6.29%. el's 4.68%
# New article number 178. la's: 8.37%. el's 3.39%
# New article number 179. la's: 8.37%. el's 3.39%
# New article number 180. la's: 9.01%. el's 7.39%
# New article number 181. la's: 5.75%. el's 7.08%
# New article number 182. la's: 9.01%. el's 7.39%
# New article number 183. la's: 5.79%. el's 7.13%
# New article number 184. la's: 9.01%. el's 7.39%
# New article number 185. la's: 5.75%. el's 7.08%
# New article number 186. la's: 9.01%. el's 7.39%
# New article number 187. la's: 5.79%. el's 7.13%
# New article number 188. la's: 8.27%. el's 4.79%
# New article number 189. la's: 8.27%. el's 4.79%
# New article number 190. la's: 6.36%. el's 6.00%
# New article number 191. la's: 6.36%. el's 6.00%
# New article number 192. la's: 7.59%. el's 4.96%
# New article number 193. la's: 7.58%. el's 5.10%
# New article number 194. la's: 7.59%. el's 4.96%
# New article number 195. la's: 7.58%. el's 5.10%
# New article number 196. la's: 10.25%. el's 6.56%
# New article number 197. la's: 10.25%. el's 6.56%
# New article number 198. la's: 9.60%. el's 5.08%
# New article number 199. la's: 10.10%. el's 3.94%
# New article number 200. la's: 6.39%. el's 6.77%
# New article number 201. la's: 10.10%. el's 3.94%
# New article number 202. la's: 6.39%. el's 6.77%
# New article number 203. la's: 5.52%. el's 4.66%
# New article number 204. la's: 5.52%. el's 4.66%
# New article number 205. la's: 9.84%. el's 6.56%
# New article number 206. la's: 9.84%. el's 6.56%
# New article number 207. la's: 5.93%. el's 5.08%
# New article number 208. la's: 5.93%. el's 5.08%
# New article number 209. la's: 9.82%. el's 4.21%
# New article number 210. la's: 9.82%. el's 4.21%
# New article number 211. la's: 3.77%. el's 6.60%
# New article number 212. la's: 8.39%. el's 6.99%
# New article number 213. la's: 4.92%. el's 6.44%
# New article number 214. la's: 3.77%. el's 6.60%
# New article number 215. la's: 3.77%. el's 6.60%
# New article number 216. la's: 8.39%. el's 6.99%
# New article number 217. la's: 4.92%. el's 6.44%
# New article number 218. la's: 3.77%. el's 6.60%
# New article number 219. la's: 10.29%. el's 2.94%
# New article number 220. la's: 10.29%. el's 2.94%
# New article number 221. la's: 9.97%. el's 6.50%
# New article number 222. la's: 7.09%. el's 3.94%
# New article number 223. la's: 9.97%. el's 6.50%
# New article number 224. la's: 7.09%. el's 3.94%
# New article number 225. la's: 6.72%. el's 7.94%
# New article number 226. la's: 6.72%. el's 7.94%
# New article number 227. la's: 5.80%. el's 5.80%
# New article number 228. la's: 4.42%. el's 4.88%
# New article number 229. la's: 4.42%. el's 4.88%
# New article number 230. la's: 5.80%. el's 5.80%
# New article number 231. la's: 4.42%. el's 4.88%
# New article number 232. la's: 4.42%. el's 4.88%
# New article number 233. la's: 7.57%. el's 7.57%
# New article number 234. la's: 7.57%. el's 7.57%
# New article number 235. la's: 7.66%. el's 8.26%
# New article number 236. la's: 10.00%. el's 6.51%
# New article number 237. la's: 7.66%. el's 8.26%
# New article number 238. la's: 10.00%. el's 6.51%
# New article number 239. la's: 6.63%. el's 5.85%
# New article number 240. la's: 6.63%. el's 5.85%
# New article number 241. la's: 6.00%. el's 4.38%
# New article number 242. la's: 6.81%. el's 8.41%
# New article number 243. la's: 7.16%. el's 4.84%
# New article number 244. la's: 7.18%. el's 4.97%
# New article number 245. la's: 6.00%. el's 4.38%
# New article number 246. la's: 6.81%. el's 8.41%
# New article number 247. la's: 7.16%. el's 4.84%
# New article number 248. la's: 7.18%. el's 4.97%
# New article number 249. la's: 4.50%. el's 7.44%
# New article number 250. la's: 7.18%. el's 5.56%
# New article number 251. la's: 4.50%. el's 7.44%
# New article number 252. la's: 7.18%. el's 5.56%
# New article number 253. la's: 6.59%. el's 6.24%
# New article number 254. la's: 5.66%. el's 4.04%
# New article number 255. la's: 5.51%. el's 3.46%
# New article number 256. la's: 6.04%. el's 8.11%
# New article number 257. la's: 7.53%. el's 5.38%
# New article number 258. la's: 6.09%. el's 3.92%
# New article number 259. la's: 6.59%. el's 6.24%
# New article number 260. la's: 5.66%. el's 4.04%
# New article number 261. la's: 5.51%. el's 3.46%
# New article number 262. la's: 6.04%. el's 8.11%
# New article number 263. la's: 7.53%. el's 5.38%
# New article number 264. la's: 6.09%. el's 3.92%
# New article number 265. la's: 6.53%. el's 4.78%
# New article number 266. la's: 6.53%. el's 4.78%
# New article number 267. la's: 7.53%. el's 4.60%
# New article number 268. la's: 7.53%. el's 4.60%
# New article number 269. la's: 7.69%. el's 6.04%
# New article number 270. la's: 7.69%. el's 6.04%
# New article number 271. la's: 5.04%. el's 8.14%
# New article number 272. la's: 4.25%. el's 5.66%
# New article number 273. la's: 5.04%. el's 8.14%
# New article number 274. la's: 4.25%. el's 5.66%
# New article number 275. la's: 7.49%. el's 6.28%
# New article number 276. la's: 7.17%. el's 6.54%
# New article number 277. la's: 7.48%. el's 6.48%
# New article number 278. la's: 7.17%. el's 6.54%
# New article number 279. la's: 7.49%. el's 6.28%
# New article number 280. la's: 7.17%. el's 6.54%
# New article number 281. la's: 7.48%. el's 6.48%
# New article number 282. la's: 7.17%. el's 6.54%
# New article number 283. la's: 9.35%. el's 4.67%
# New article number 284. la's: 6.63%. el's 9.18%
# New article number 285. la's: 9.38%. el's 4.69%
# New article number 286. la's: 6.63%. el's 9.18%
# New article number 287. la's: 9.35%. el's 4.67%
# New article number 288. la's: 6.63%. el's 9.18%
# New article number 289. la's: 9.38%. el's 4.69%
# New article number 290. la's: 6.63%. el's 9.18%
# New article number 291. la's: 6.18%. el's 5.23%
# New article number 292. la's: 6.18%. el's 5.23%
# New article number 293. la's: 7.68%. el's 6.96%
# New article number 294. la's: 7.68%. el's 6.96%
# New article number 295. la's: 5.37%. el's 7.76%
# New article number 296. la's: 5.47%. el's 7.69%
# New article number 297. la's: 5.37%. el's 7.76%
# New article number 298. la's: 5.47%. el's 7.69%
# New article number 299. la's: 8.27%. el's 4.79%
# New article number 300. la's: 8.27%. el's 4.79%
# New article number 301. la's: 8.18%. el's 5.13%
# New article number 302. la's: 8.17%. el's 5.12%
# New article number 303. la's: 8.18%. el's 5.13%
# New article number 304. la's: 8.17%. el's 5.12%
# New article number 305. la's: 8.27%. el's 5.40%
# New article number 306. la's: 8.27%. el's 5.40%
# New article number 307. la's: 8.27%. el's 5.40%
# New article number 308. la's: 8.27%. el's 5.40%
# New article number 309. la's: 4.19%. el's 6.59%
# New article number 310. la's: 8.74%. el's 4.81%
# New article number 311. la's: 4.45%. el's 6.82%
# New article number 312. la's: 8.74%. el's 4.81%
# New article number 313. la's: 7.14%. el's 3.85%
# New article number 314. la's: 7.56%. el's 6.53%
# New article number 315. la's: 7.56%. el's 6.53%
# New article number 316. la's: 6.44%. el's 8.91%
# New article number 317. la's: 6.44%. el's 8.91%
# New article number 318. la's: 6.44%. el's 8.91%
# New article number 319. la's: 6.44%. el's 8.91%
# New article number 320. la's: 5.86%. el's 5.86%
# New article number 321. la's: 5.87%. el's 5.77%
# New article number 322. la's: 5.86%. el's 5.86%
# New article number 323. la's: 5.87%. el's 5.77%
# New article number 324. la's: 5.47%. el's 4.66%
# New article number 325. la's: 5.47%. el's 4.66%
# New article number 326. la's: 9.64%. el's 5.72%
# New article number 327. la's: 9.64%. el's 5.72%
# New article number 328. la's: 6.06%. el's 5.76%
# New article number 329. la's: 6.06%. el's 5.76%
# New article number 330. la's: 6.06%. el's 5.76%
# New article number 331. la's: 6.06%. el's 5.76%
# New article number 332. la's: 5.88%. el's 3.36%
# New article number 333. la's: 5.83%. el's 3.33%
# New article number 334. la's: 5.88%. el's 3.36%
# New article number 335. la's: 5.83%. el's 3.33%
# New article number 336. la's: 6.39%. el's 7.55%
# New article number 337. la's: 6.39%. el's 7.55%
# New article number 338. la's: 9.94%. el's 5.59%
# New article number 339. la's: 9.94%. el's 5.59%
# New article number 340. la's: 5.36%. el's 4.20%
# New article number 341. la's: 5.36%. el's 4.20%
# New article number 342. la's: 4.81%. el's 3.61%
# New article number 343. la's: 4.81%. el's 3.61%
# New article number 344. la's: 6.17%. el's 5.29%
# New article number 345. la's: 6.17%. el's 5.29%
# New article number 346. la's: 7.51%. el's 3.66%
# New article number 347. la's: 7.48%. el's 4.36%
# New article number 348. la's: 7.51%. el's 3.66%
# New article number 349. la's: 7.48%. el's 4.36%
# New article number 350. la's: 7.59%. el's 4.43%
# New article number 351. la's: 7.59%. el's 4.43%
# New article number 352. la's: 4.11%. el's 5.14%
# New article number 353. la's: 5.59%. el's 5.59%
# New article number 354. la's: 4.11%. el's 5.14%
# New article number 355. la's: 5.59%. el's 5.59%
# New article number 356. la's: 4.37%. el's 7.69%
# New article number 357. la's: 6.30%. el's 7.48%
# New article number 358. la's: 5.80%. el's 4.35%
# New article number 359. la's: 5.36%. el's 5.68%
# New article number 360. la's: 3.59%. el's 5.99%
# New article number 361. la's: 4.58%. el's 7.64%
# New article number 362. la's: 5.80%. el's 4.35%
# New article number 363. la's: 5.41%. el's 5.87%
# New article number 364. la's: 3.64%. el's 4.85%
# New article number 365. la's: 6.30%. el's 7.09%
# New article number 366. la's: 4.37%. el's 7.69%
# New article number 367. la's: 6.30%. el's 7.48%
# New article number 368. la's: 5.80%. el's 4.35%
# New article number 369. la's: 5.36%. el's 5.68%
# New article number 370. la's: 3.59%. el's 5.99%
# New article number 371. la's: 4.58%. el's 7.64%
# New article number 372. la's: 5.80%. el's 4.35%
# New article number 373. la's: 5.41%. el's 5.87%
# New article number 374. la's: 3.64%. el's 4.85%
# New article number 375. la's: 6.30%. el's 7.09%
# New article number 376. la's: 8.14%. el's 8.27%
# New article number 377. la's: 8.16%. el's 8.42%
# New article number 378. la's: 8.14%. el's 8.27%
# New article number 379. la's: 8.16%. el's 8.42%
# New article number 380. la's: 6.83%. el's 7.55%
# New article number 381. la's: 4.47%. el's 5.59%
# New article number 382. la's: 5.65%. el's 6.41%
# New article number 383. la's: 6.83%. el's 7.55%
# New article number 384. la's: 4.47%. el's 5.59%
# New article number 385. la's: 5.65%. el's 6.41%
# New article number 386. la's: 6.27%. el's 7.59%
# New article number 387. la's: 6.27%. el's 7.59%
# New article number 388. la's: 4.98%. el's 9.05%
# New article number 389. la's: 5.26%. el's 8.77%
# New article number 390. la's: 4.98%. el's 9.05%
# New article number 391. la's: 5.26%. el's 8.77%
# New article number 392. la's: 5.39%. el's 5.39%
# New article number 393. la's: 5.39%. el's 5.39%
# New article number 394. la's: 5.39%. el's 5.39%
# New article number 395. la's: 5.39%. el's 5.39%
# New article number 396. la's: 6.93%. el's 7.43%
# New article number 397. la's: 6.93%. el's 7.43%
# New article number 398. la's: 6.85%. el's 5.48%
# New article number 399. la's: 6.85%. el's 5.48%
# New article number 400. la's: 5.28%. el's 8.44%
# New article number 401. la's: 5.25%. el's 8.66%
# New article number 402. la's: 5.28%. el's 8.44%
# New article number 403. la's: 5.25%. el's 8.66%
# New article number 404. la's: 8.29%. el's 3.31%
# New article number 405. la's: 8.13%. el's 7.39%
# New article number 406. la's: 6.57%. el's 9.09%
# New article number 407. la's: 8.29%. el's 3.31%
# New article number 408. la's: 6.16%. el's 4.38%
# New article number 409. la's: 6.57%. el's 9.09%
# New article number 410. la's: 8.15%. el's 4.35%
# New article number 411. la's: 8.29%. el's 3.31%
# New article number 412. la's: 8.13%. el's 7.39%
# New article number 413. la's: 6.57%. el's 9.09%
# New article number 414. la's: 8.29%. el's 3.31%
# New article number 415. la's: 6.16%. el's 4.38%
# New article number 416. la's: 6.57%. el's 9.09%
# New article number 417. la's: 8.15%. el's 4.35%
# New article number 418. la's: 9.25%. el's 5.48%
# New article number 419. la's: 9.25%. el's 5.48%
# New article number 420. la's: 4.95%. el's 5.77%
# New article number 421. la's: 7.16%. el's 8.99%
# New article number 422. la's: 4.79%. el's 4.79%
# New article number 423. la's: 4.95%. el's 5.77%
# New article number 424. la's: 7.16%. el's 8.99%
# New article number 425. la's: 4.79%. el's 4.79%
# New article number 426. la's: 7.67%. el's 5.44%
# New article number 427. la's: 7.67%. el's 5.44%
# New article number 428. la's: 6.96%. el's 6.52%
# New article number 429. la's: 8.07%. el's 7.76%
# New article number 430. la's: 6.96%. el's 6.52%
# New article number 431. la's: 8.07%. el's 7.76%
# New article number 432. la's: 4.47%. el's 6.20%
# New article number 433. la's: 8.35%. el's 4.27%
# New article number 434. la's: 4.47%. el's 6.20%
# New article number 435. la's: 7.46%. el's 6.72%
# New article number 436. la's: 6.72%. el's 6.13%
# New article number 437. la's: 4.47%. el's 6.20%
# New article number 438. la's: 8.35%. el's 4.27%
# New article number 439. la's: 4.47%. el's 6.20%
# New article number 440. la's: 7.46%. el's 6.72%
# New article number 441. la's: 6.72%. el's 6.13%
# New article number 442. la's: 5.87%. el's 4.86%
# New article number 443. la's: 5.87%. el's 4.86%
# New article number 444. la's: 5.69%. el's 5.49%
# New article number 445. la's: 5.69%. el's 5.49%
# New article number 446. la's: 13.64%. el's 5.19%
# New article number 447. la's: 13.64%. el's 5.19%
# New article number 448. la's: 9.48%. el's 5.17%
# New article number 449. la's: 11.03%. el's 6.55%
# New article number 450. la's: 9.48%. el's 5.17%
# New article number 451. la's: 9.48%. el's 5.17%
# New article number 452. la's: 11.03%. el's 6.55%
# New article number 453. la's: 9.48%. el's 5.17%
# New article number 454. la's: 8.45%. el's 3.13%
# New article number 455. la's: 8.45%. el's 3.13%
# New article number 456. la's: 8.09%. el's 5.15%
# New article number 457. la's: 8.09%. el's 5.15%
# New article number 458. la's: 5.57%. el's 3.45%
# New article number 459. la's: 5.57%. el's 3.45%
# New article number 460. la's: 6.94%. el's 4.17%
# New article number 461. la's: 6.94%. el's 4.17%
# New article number 462. la's: 8.44%. el's 7.92%
# New article number 463. la's: 8.44%. el's 7.92%
# New article number 464. la's: 8.54%. el's 6.90%
# New article number 465. la's: 8.54%. el's 6.90%
# New article number 466. la's: 8.23%. el's 7.73%
# New article number 467. la's: 8.23%. el's 7.73%
# New article number 468. la's: 8.23%. el's 7.73%
# New article number 469. la's: 8.23%. el's 7.73%
# New article number 470. la's: 5.65%. el's 6.30%
# New article number 471. la's: 5.36%. el's 7.26%
# New article number 472. la's: 11.46%. el's 7.64%
# New article number 473. la's: 9.59%. el's 5.48%
# New article number 474. la's: 9.59%. el's 5.48%
# New article number 475. la's: 4.47%. el's 6.70%
# New article number 476. la's: 4.47%. el's 6.70%
# New article number 477. la's: 5.33%. el's 7.46%
# New article number 478. la's: 5.33%. el's 7.46%
# New article number 479. la's: 5.33%. el's 7.46%
# New article number 480. la's: 5.33%. el's 7.46%
# New article number 481. la's: 5.86%. el's 6.71%
# New article number 482. la's: 5.86%. el's 6.71%
# New article number 483. la's: 7.88%. el's 3.64%
# New article number 484. la's: 6.98%. el's 6.01%
# New article number 485. la's: 5.86%. el's 6.71%
# New article number 486. la's: 5.86%. el's 6.71%
# New article number 487. la's: 7.88%. el's 3.64%
# New article number 488. la's: 6.98%. el's 6.01%
# New article number 489. la's: 4.84%. el's 7.96%
# New article number 490. la's: 4.84%. el's 7.96%
# New article number 491. la's: 8.00%. el's 5.33%
# New article number 492. la's: 8.00%. el's 5.33%
# New article number 493. la's: 6.47%. el's 5.04%
# New article number 494. la's: 6.47%. el's 5.04%
# New article number 495. la's: 1.61%. el's 1.61%
# New article number 496. la's: 1.61%. el's 1.61%
# New article number 497. la's: 8.26%. el's 7.44%
# New article number 498. la's: 8.26%. el's 7.44%
# New article number 499. la's: 6.69%. el's 6.28%
# New article number 500. la's: 6.69%. el's 6.28%
# New article number 501. la's: 9.11%. el's 4.77%
# New article number 502. la's: 9.11%. el's 4.77%
# New article number 503. la's: 9.11%. el's 4.77%
# New article number 504. la's: 9.11%. el's 4.77%
# New article number 505. la's: 5.75%. el's 3.22%
# New article number 506. la's: 5.75%. el's 3.22%
# New article number 507. la's: 4.21%. el's 13.68%
# New article number 508. la's: 4.21%. el's 13.68%
# New article number 509. la's: 5.54%. el's 5.94%
# New article number 510. la's: 5.54%. el's 5.94%
# New article number 511. la's: 10.20%. el's 7.14%
# New article number 512. la's: 10.20%. el's 7.14%
# New article number 513. la's: 6.35%. el's 5.14%
# New article number 514. la's: 6.35%. el's 5.14%
# New article number 515. la's: 5.74%. el's 8.13%
# New article number 516. la's: 5.74%. el's 8.13%
# New article number 517. la's: 9.68%. el's 5.65%
# New article number 518. la's: 9.17%. el's 5.00%
# New article number 519. la's: 9.68%. el's 5.65%
# New article number 520. la's: 9.17%. el's 5.00%
# New article number 521. la's: 1.09%. el's 8.70%
# New article number 522. la's: 1.09%. el's 8.70%
# New article number 523. la's: 6.22%. el's 8.00%
# New article number 524. la's: 6.22%. el's 8.00%
# New article number 525. la's: 7.38%. el's 6.31%
# New article number 526. la's: 7.38%. el's 6.31%
# New article number 527. la's: 4.47%. el's 6.19%
# New article number 528. la's: 4.47%. el's 6.19%
# New article number 529. la's: 5.70%. el's 5.44%
# New article number 530. la's: 5.70%. el's 5.44%
# New article number 531. la's: 8.50%. el's 5.08%
# New article number 532. la's: 9.91%. el's 7.21%
# New article number 533. la's: 8.50%. el's 5.08%
# New article number 534. la's: 9.91%. el's 7.21%
# New article number 535. la's: 6.83%. el's 6.39%
# New article number 536. la's: 5.69%. el's 6.89%
# New article number 537. la's: 6.87%. el's 6.55%
# New article number 538. la's: 6.83%. el's 6.39%
# New article number 539. la's: 5.69%. el's 6.89%
# New article number 540. la's: 6.87%. el's 6.55%
# New article number 541. la's: 4.88%. el's 3.66%
# New article number 542. la's: 8.06%. el's 6.85%
# New article number 543. la's: 4.88%. el's 3.66%
# New article number 544. la's: 8.06%. el's 6.85%
# New article number 545. la's: 6.51%. el's 5.60%
# New article number 546. la's: 6.51%. el's 5.60%
# New article number 547. la's: 7.29%. el's 7.29%
# New article number 548. la's: 7.27%. el's 7.54%
# New article number 549. la's: 7.29%. el's 7.29%
# New article number 550. la's: 7.27%. el's 7.54%
# New article number 551. la's: 4.44%. el's 7.82%
# New article number 552. la's: 7.45%. el's 5.19%
# New article number 553. la's: 8.18%. el's 6.29%
# New article number 554. la's: 4.52%. el's 7.96%
# New article number 555. la's: 7.49%. el's 5.08%
# New article number 556. la's: 4.89%. el's 8.70%
# New article number 557. la's: 4.44%. el's 7.82%
# New article number 558. la's: 7.45%. el's 5.19%
# New article number 559. la's: 8.18%. el's 6.29%
# New article number 560. la's: 4.52%. el's 7.96%
# New article number 561. la's: 7.49%. el's 5.08%
# New article number 562. la's: 4.89%. el's 8.70%
# New article number 563. la's: 7.95%. el's 9.09%
# New article number 564. la's: 4.61%. el's 4.61%
# New article number 565. la's: 7.64%. el's 5.10%
# New article number 566. la's: 5.68%. el's 10.23%
# New article number 567. la's: 4.14%. el's 4.42%
# New article number 568. la's: 7.95%. el's 9.09%
# New article number 569. la's: 4.61%. el's 4.61%
# New article number 570. la's: 7.64%. el's 5.10%
# New article number 571. la's: 5.68%. el's 10.23%
# New article number 572. la's: 4.14%. el's 4.42%
# New article number 573. la's: 6.19%. el's 7.08%
# New article number 574. la's: 6.19%. el's 7.08%
# New article number 575. la's: 7.30%. el's 7.30%
# New article number 576. la's: 5.50%. el's 4.59%
# New article number 577. la's: 7.30%. el's 7.30%
# New article number 578. la's: 6.19%. el's 7.08%
# New article number 579. la's: 6.19%. el's 7.08%
# New article number 580. la's: 6.19%. el's 7.08%
# New article number 581. la's: 7.30%. el's 7.30%
# New article number 582. la's: 5.50%. el's 4.59%
# New article number 583. la's: 7.30%. el's 7.30%
# New article number 584. la's: 6.19%. el's 7.08%
# New article number 585. la's: 5.22%. el's 5.48%
# New article number 586. la's: 5.20%. el's 5.94%
# New article number 587. la's: 5.22%. el's 5.48%
# New article number 588. la's: 5.20%. el's 5.94%
# New article number 589. la's: 6.48%. el's 5.90%
# New article number 590. la's: 6.15%. el's 8.87%
# New article number 591. la's: 6.30%. el's 5.59%
# New article number 592. la's: 6.48%. el's 5.90%
# New article number 593. la's: 6.15%. el's 8.87%
# New article number 594. la's: 6.30%. el's 5.59%
# New article number 595. la's: 5.92%. el's 6.59%
# New article number 596. la's: 5.92%. el's 6.59%
# New article number 597. la's: 5.95%. el's 4.76%
# New article number 598. la's: 5.92%. el's 6.59%
# New article number 599. la's: 5.92%. el's 6.59%
# New article number 600. la's: 5.95%. el's 4.76%
# New article number 601. la's: 5.41%. el's 2.84%
# New article number 602. la's: 2.53%. el's 9.09%
# New article number 603. la's: 7.03%. el's 5.41%
# New article number 604. la's: 5.41%. el's 2.84%
# New article number 605. la's: 2.53%. el's 9.09%
# New article number 606. la's: 7.03%. el's 5.41%
# New article number 607. la's: 6.96%. el's 4.31%
# New article number 608. la's: 5.04%. el's 5.04%
# New article number 609. la's: 7.24%. el's 5.91%
# New article number 610. la's: 6.96%. el's 4.31%
# New article number 611. la's: 5.04%. el's 5.04%
# New article number 612. la's: 7.24%. el's 5.91%
# New article number 613. la's: 6.99%. el's 5.41%
# New article number 614. la's: 8.18%. el's 5.45%
# New article number 615. la's: 8.18%. el's 5.45%
# New article number 616. la's: 3.28%. el's 8.03%
# New article number 617. la's: 0.00%. el's 10.17%
# New article number 618. la's: 6.97%. el's 5.66%
# New article number 619. la's: 8.04%. el's 7.14%
# New article number 620. la's: 3.35%. el's 7.43%
# New article number 621. la's: 6.99%. el's 5.41%
# New article number 622. la's: 8.18%. el's 5.45%
# New article number 623. la's: 8.18%. el's 5.45%
# New article number 624. la's: 3.28%. el's 8.03%
# New article number 625. la's: 0.00%. el's 10.17%
# New article number 626. la's: 6.97%. el's 5.66%
# New article number 627. la's: 8.04%. el's 7.14%
# New article number 628. la's: 3.35%. el's 7.43%
# New article number 629. la's: 7.12%. el's 6.82%
# New article number 630. la's: 7.12%. el's 6.82%
# New article number 631. la's: 7.12%. el's 6.82%
# New article number 632. la's: 7.12%. el's 6.82%
# New article number 633. la's: 5.45%. el's 6.17%
# New article number 634. la's: 8.05%. el's 6.75%
# New article number 635. la's: 13.89%. el's 8.73%
# New article number 636. la's: 5.45%. el's 6.17%
# New article number 637. la's: 8.05%. el's 6.75%
# New article number 638. la's: 13.89%. el's 8.73%
# New article number 639. la's: 6.49%. el's 6.85%
# New article number 640. la's: 4.22%. el's 5.19%
# New article number 641. la's: 6.69%. el's 6.93%
# New article number 642. la's: 6.49%. el's 6.85%
# New article number 643. la's: 4.22%. el's 5.19%
# New article number 644. la's: 6.69%. el's 6.93%
# New article number 645. la's: 4.31%. el's 3.08%
# New article number 646. la's: 4.31%. el's 3.08%
# New article number 647. la's: 9.33%. el's 12.00%
# New article number 648. la's: 8.32%. el's 7.44%
# New article number 649. la's: 9.33%. el's 12.00%
# New article number 650. la's: 8.32%. el's 7.44%
# New article number 651. la's: 5.93%. el's 6.60%
# New article number 652. la's: 9.70%. el's 6.70%
# New article number 653. la's: 3.85%. el's 10.99%
# New article number 654. la's: 3.85%. el's 10.99%
# New article number 655. la's: 6.10%. el's 8.05%
# New article number 656. la's: 5.94%. el's 6.61%
# New article number 657. la's: 9.70%. el's 6.70%
# New article number 658. la's: 5.93%. el's 6.60%
# New article number 659. la's: 9.70%. el's 6.70%
# New article number 660. la's: 3.85%. el's 10.99%
# New article number 661. la's: 3.85%. el's 10.99%
# New article number 662. la's: 6.10%. el's 8.05%
# New article number 663. la's: 5.94%. el's 6.61%
# New article number 664. la's: 9.70%. el's 6.70%
# New article number 665. la's: 9.72%. el's 2.78%
# New article number 666. la's: 6.94%. el's 5.07%
# New article number 667. la's: 8.33%. el's 7.64%
# New article number 668. la's: 9.72%. el's 2.78%
# New article number 669. la's: 6.94%. el's 5.07%
# New article number 670. la's: 8.33%. el's 7.64%
# New article number 671. la's: 5.84%. el's 6.81%
# New article number 672. la's: 8.26%. el's 4.88%
# New article number 673. la's: 5.26%. el's 6.58%
# New article number 674. la's: 5.84%. el's 6.81%
# New article number 675. la's: 8.26%. el's 4.88%
# New article number 676. la's: 5.26%. el's 6.58%
# New article number 677. la's: 8.10%. el's 7.57%
# New article number 678. la's: 4.61%. el's 7.09%
# New article number 679. la's: 6.17%. el's 7.14%
# New article number 680. la's: 8.10%. el's 7.57%
# New article number 681. la's: 4.61%. el's 7.09%
# New article number 682. la's: 6.17%. el's 7.14%
# New article number 683. la's: 6.26%. el's 6.45%
# New article number 684. la's: 6.26%. el's 6.45%
# New article number 685. la's: 9.80%. el's 7.09%
# New article number 686. la's: 6.26%. el's 6.45%
# New article number 687. la's: 9.80%. el's 7.09%
# New article number 688. la's: 7.12%. el's 6.56%

# %% [markdown]
# ## Correlating words and visualizing them

# %%
from scipy.stats import pearsonr, spearmanr
import pylab as plt

frequency_las = []
frequency_els = []

with open("./data/Pablo_Iglesias_Podemos.csv") as f:
    for i,line in enumerate(f):
        date, newspaper, content = line.split("\t")
        number_words = len(content.split(" "))

        frequency_las.append(100*content.count("la")/number_words)
        frequency_els.append(100*content.count("el")/number_words)


print(frequency_las[:10])
print(frequency_els[:10])
        
pearson_corr,pearson_pvalue = pearsonr(frequency_las,frequency_els)
spearmanr_corr,spearmanr_pvalue = spearmanr(frequency_las,frequency_els)

print(pearson_corr,pearson_pvalue)
print(spearmanr_corr,spearmanr_pvalue)
# Out:
# [6.261510128913444, 6.261510128913444, 9.797297297297296, 6.261510128913444, 9.797297297297296, 7.122905027932961, 5.357142857142857, 10.0, 8.816120906801007, 5.483870967741935]
# [6.445672191528545, 6.445672191528545, 7.094594594594595, 6.445672191528545, 7.094594594594595, 6.564245810055866, 4.464285714285714, 5.365853658536586, 6.54911838790932, 5.0]
# -0.0594241938359 0.119148064261
# -0.0589721980327 0.121987381518

# %%
plt.plot(frequency_las,frequency_els,"o")
plt.xlabel("Frequency of las")
plt.ylabel("Frequency of els")
plt.title("Just a kindof meaningless plot")
plt.show()

# %% [markdown]
# ## Counting all the words and plot histagrams

# %%
import pylab as plt
import numpy as np

def make_line_hist(x,minValue,maxValue,nbins=10,logscale=False):
    """
    make a line histogram (instead of bars, just the top line)
    """
    if logscale:
        freqs,bins = np.histogram(x,bins=np.logspace(np.log10(minValue),np.log10(maxValue),nbins),normed=True) 
    else:
        freqs,bins = np.histogram(x,bins=np.linspace(minValue,maxValue,nbins),normed=True)
        
    
    plt.plot((bins[:-1]+bins[1:])/2,freqs)
    return freqs
    
### Get the distribution of words and plot histogram
from collections import Counter
with open("./data/Pablo_Iglesias_Podemos.csv") as f:
    lines = sorted(set(f.readlines()))
    for line in lines:
        date, newspaper, content = line.rsplit("\t")
        number_words = len(content.split(" "))

        counter = Counter(content.split(" "))
        print(counter.most_common(5))
        elements,count = zip(*counter.most_common())
        freq = 100*np.array(count)/number_words
        
        freqs = make_line_hist(freq,0.001,5,10,logscale=True)
     
        
plt.legend([0,1,2,3,4,5])
plt.xlabel("Frequency of a word")
plt.ylabel("Frequency of that frequency")
plt.title("More to the left = more diversity")
plt.show()
# Out:
# [('de', 43), ('que', 31), ('y', 27), ('el', 22), ('en', 22)]
# [('de', 43), ('el', 30), ('la', 27), ('a', 22), ('en', 22)]
# [('de', 10), ('la', 8), ('el', 6), ('que', 4), ('los', 3)]
# [('de', 20), ('el', 16), ('los', 12), ('que', 12), ('a', 8)]
# [('de', 26), ('el', 23), ('y', 19), ('en', 15), ('con', 13)]

# %% [markdown]
# ## Visualizing frequency of a word over time
# ### Step 1. Give some format

# %%
##Formats the date

from dateutil.parser import parse
with open("./data/Pablo_Iglesias_Podemos.csv") as f, open("./data/Pablo_Iglesias_Podemos_date_formatted.csv","w+") as fOut:
    lines = sorted(set(f.readlines()))
    for i,line in enumerate(lines):
        date, newspaper, content = line.rsplit("\t")
        number_words = len(content.split(" "))
        corruption = content.count("corrup")
        date = parse(date,fuzzy=True,dayfirst=True)
        fOut.write("{0}\t{1}\n".format(date.date(),100*corruption/number_words))

with open("./data/Albert_Rivera_Ciudadanos.csv") as f, open("./data/Albert_Rivera_Ciudadanos_date_formatted.csv","w+") as fOut:
    lines = sorted(set(f.readlines()))
    for i,line in enumerate(lines):
        date, newspaper, content = line.rsplit("\t")
        number_words = len(content.split(" "))
        corruption = content.count("corrup")        
        date = parse(date,fuzzy=True,dayfirst=True)
        fOut.write("{0}\t{1}\n".format(date.date(),100*corruption/number_words))

# %% [markdown]
# ### Step 2. Group (freq is too low)

# %%
import pandas as pd
df = pd.read_csv("./data/Pablo_Iglesias_Podemos_date_formatted.csv",sep="\t",header=None,index_col=None)
df.columns = ["Date","Perc"]
print(df.loc[:10,:])
# Out:
#           Date      Perc
# 0   2015-12-01  0.000000
# 1   2015-12-01  0.000000
# 2   2015-12-01  0.000000
# 3   2015-12-01  0.000000
# 4   2015-12-01  0.000000
# 5   2015-12-01  0.000000
# 6   2015-12-01  0.000000
# 7   2015-12-01  0.869565
# 8   2015-12-01  0.000000
# 9   2015-12-01  0.000000
# 10  2015-12-01  0.000000

# %%
### Group by date so we can plot
df_podemos = pd.read_csv("./data/Pablo_Iglesias_Podemos_date_formatted.csv",sep="\t",header=None,index_col=None)
df_podemos.columns = ["Date","Perc"]
df_podemos = df_podemos.groupby("Date").mean().reset_index()


df_ciudadnos = pd.read_csv("./data/Albert_Rivera_Ciudadanos_date_formatted.csv",sep="\t",header=None,index_col=None)
df_ciudadnos.columns = ["Date","Perc"]
df_ciudadnos = df_ciudadnos.groupby("Date").mean().reset_index()

plt.plot(df_podemos["Date"],df_podemos["Perc"])
plt.plot(df_ciudadnos["Date"],df_ciudadnos["Perc"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-50688696dbeb> in <module>()
#       9 df_ciudadnos = df_ciudadnos.groupby("Date").mean().reset_index()
#      10
# ---> 11 plt.plot(df_podemos["Date"],df_podemos["Perc"])
#      12 plt.plot(df_ciudadnos["Date"],df_ciudadnos["Perc"])
#      13 plt.show()
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1426
#    1427         for line in self._get_lines(*args, **kwargs):
# -> 1428             self.add_line(line)
#    1429             lines.append(line)
#    1430
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1697             line.set_clip_path(self.patch)
#    1698
# -> 1699         self._update_line_limits(line)
#    1700         if not line.get_label():
#    1701             line.set_label('_line%d' % len(self.lines))
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1708         Figures out the data limit of the given line, updating self.dataLim.
#    1709         """
# -> 1710         path = line.get_path()
#    1711         if path.vertices.size == 0:
#    1712             return
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in get_path(self)
#     924         """
#     925         if self._invalidy or self._invalidx:
# --> 926             self.recache()
#     927         return self._path
#     928
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in recache(self, always)
#     609                 x = ma.asarray(xconv, np.float_).filled(np.nan)
#     610             else:
# --> 611                 x = np.asarray(xconv, np.float_)
#     612             x = x.ravel()
#     613         else:
#
# /home/javiergb/Programs/anaconda3/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     472
#     473     """
# --> 474     return array(a, dtype, copy=False, order=order)
#     475
#     476 def asanyarray(a, dtype=None, order=None):
#
# ValueError: could not convert string to float: '2016-01-19'

# %%
## Formats the date again, to plot it
from dateutil.parser import parse
df_podemos = pd.read_csv("./data/Pablo_Iglesias_Podemos_date_formatted.csv",sep="\t",header=None,index_col=None)
df_podemos.columns = ["Date","Perc"]
df_podemos = df_podemos.groupby("Date").mean().reset_index()
df_podemos = df_podemos.loc[df_podemos["Perc"]>0,:]

dates_podemos = []
for date in df_podemos["Date"]:
    dates_podemos.append(parse(date))

df_ciudadnos = pd.read_csv("./data/Albert_Rivera_Ciudadanos_date_formatted.csv",sep="\t",header=None,index_col=None)
df_ciudadnos.columns = ["Date","Perc"]
df_ciudadnos = df_ciudadnos.groupby("Date").mean().reset_index()
df_ciudadnos = df_ciudadnos.loc[df_ciudadnos["Perc"]>0,:]

dates_ciudadanos = []
for date in df_ciudadnos["Date"]:
    dates_ciudadanos.append(parse(date))


plt.figure(figsize=(12,5))
plt.plot(dates_podemos,df_podemos["Perc"],"o",color="Red")
plt.plot(dates_ciudadanos,df_ciudadnos["Perc"],"o",color="Blue")

elections = parse("Dec 20, 2015")
plt.plot([elections,elections],[0,0.8])
plt.show()

# %% [markdown]
# ## Cross-correlation time series of frequencies (Hints on causality)

# %%
from dateutil.parser import parse
from scipy.stats import pearsonr, spearmanr

df_podemos = pd.read_csv("./data/Pablo_Iglesias_Podemos_date_formatted.csv",sep="\t",header=None,index_col=None)
df_podemos.columns = ["Date","Perc"]
df_podemos = df_podemos.groupby("Date").mean().reset_index()
df_podemos = df_podemos.loc[df_podemos["Perc"]>0,:]

df_ciudadnos = pd.read_csv("./data/Albert_Rivera_Ciudadanos_date_formatted.csv",sep="\t",header=None,index_col=None)
df_ciudadnos.columns = ["Date","Perc"]
df_ciudadnos = df_ciudadnos.groupby("Date").mean().reset_index()
df_ciudadnos = df_ciudadnos.loc[df_ciudadnos["Perc"]>0,:]

# %%
#Correlation
df_both = pd.merge(df_podemos,df_ciudadnos,on="Date")
print(df_both)
plt.plot(df_both["Perc_x"],df_both["Perc_y"],"o")
plt.xlabel("Perc corruption news in Podemos")
plt.ylabel("Perc corruption news in Ciudadanos")
spearmanr_corr,spearmanr_pvalue = spearmanr(df_both["Perc_x"],df_both["Perc_y"])
plt.title("Correlation: {0:2.2f} P-value: {1:2.2f}".format(spearmanr_corr,spearmanr_pvalue))

plt.show()
# Out:
#          Date    Perc_x    Perc_y
# 0  2015-12-02  0.045045  0.073358
# 1  2015-12-04  0.254674  0.157816
# 2  2015-12-09  0.162224  0.102564
# 3  2015-12-12  0.269706  0.723186
# 4  2015-12-16  0.157120  0.113122
# 5  2015-12-19  0.038124  0.022862
# 6  2015-12-20  0.034619  0.048924
# 7  2015-12-21  0.055280  0.060721
# 8  2015-12-28  0.054705  0.084746
# 9  2016-01-12  0.074020  0.066578

# %%
def cross_correlation(x,y,time):
    """
    Calculates the normalized cross-correlation and plots it
    """    
    import numpy as np
    modeC = "same"
    x = (x - np.mean(x))/np.std(x)
    y =  (y - np.mean(y))/np.std(y)

    timeInt = np.diff(time).mean().days
    numPoints = len(x)
    fig = plt.figure(figsize=(6,3.5))        
    d = np.correlate(y,x,modeC)

    plt.plot([0,0],[-0.5,1],color="grey")
    plt.xlabel("Lag")
    plt.ylabel("Correlation")
    plt.plot(np.linspace(len(x)/2*timeInt,-len(x)/2*timeInt,len(x)),d/numPoints)

        
dates = []
for date in df_both["Date"]:
    dates.append(parse(date))
    
cross_correlation(df_both["Perc_x"],df_both["Perc_y"],dates)
print("Typically news talk about corruption in Podemos first (lag to the left) and for a while \n \
      (elevated for a couple weeks) before talking about corruption in Ciudadanos ")
# Out:
# Typically news talk about corruption in Podemos first (lag to the left) and for a while
#        (elevated for a couple weeks) before talking about corruption in Ciudadanos

# %% [markdown]
# ## Statistics

# %%
import numpy as np

#t-test
from scipy.stats import ttest_ind 
population1 = np.random.normal(10,5,size=1000)
population2 = np.random.normal(9,5,size=1000)

make_line_hist(population1,-10,30,10)
make_line_hist(population2,-10,30,10)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

print(ttest_ind(population1,population2))

#non-parametric alternative of t-test
from scipy.stats import mannwhitneyu
print(mannwhitneyu(population1,population2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a7ddf75cd267> in <module>()
#       6 population2 = np.random.normal(9,5,size=1000)
#       7
# ----> 8 make_line_hist(population1,-10,30,10)
#       9 make_line_hist(population2,-10,30,10)
#      10 plt.xlabel("Value")
#
# NameError: name 'make_line_hist' is not defined

# %%
#anova
import numpy as np
from scipy.stats import f_oneway
population3 = np.random.normal(9.5,5,size=1000)
print(f_oneway(population1, population2, population3)  )
# Out:
# F_onewayResult(statistic=13.599112041486856, pvalue=1.3201359127709691e-06)

# %%
#linear regression
import pandas as pd
import statsmodels.formula.api as sm

df = pd.DataFrame(dict({"X":population1, "Y1":population2,"Y2":population3}))


result = sm.ols(formula="X ~ Y1 *Y2", data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      X   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5799
# Date:                Thu, 21 Jan 2016   Prob (F-statistic):              0.628
# Time:                        13:06:56   Log-Likelihood:                -3007.4
# No. Observations:                1000   AIC:                             6023.
# Df Residuals:                     996   BIC:                             6042.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     10.4559      0.661     15.828      0.000         9.160    11.752
# Y1            -0.0249      0.064     -0.387      0.699        -0.151     0.101
# Y2            -0.0223      0.060     -0.370      0.711        -0.141     0.096
# Y1:Y2         -0.0006      0.006     -0.102      0.919        -0.012     0.011
# ==============================================================================
# Omnibus:                        0.380   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.827   Jarque-Bera (JB):                0.399
# Skew:                          -0.047   Prob(JB):                        0.819
# Kurtosis:                       2.975   Cond. No.                         468.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(df_both)
from scipy.stats import mannwhitneyu
print(mannwhitneyu(df_both["Perc_x"],df_both["Perc_y"]))
# Out:
#          Date    Perc_x    Perc_y
# 0  2015-12-02  0.045045  0.073358
# 1  2015-12-04  0.254674  0.157816
# 2  2015-12-09  0.162224  0.102564
# 3  2015-12-12  0.269706  0.723186
# 4  2015-12-16  0.157120  0.113122
# 5  2015-12-19  0.038124  0.022862
# 6  2015-12-20  0.034619  0.048924
# 7  2015-12-21  0.055280  0.060721
# 8  2015-12-28  0.054705  0.084746
# 9  2016-01-12  0.074020  0.066578
# MannwhitneyuResult(statistic=47.0, pvalue=0.42505336956926293)

# %% [markdown]
# ## Teaser for next day: Happiness
# http://www.uvm.edu/storylab/2014/11/09/the-happiest-character-on-seinfeld-was/

# %%
from labMTsimple.storyLab import *

lang = 'english'
labMT,labMTvector,labMTwordList = emotionFileReader(stopval=0.0,lang=lang,returnVector=True)
#Then we can score the text and get the word vector at the same time:
saturdayValence,saturdayFvec = emotion("saturday",labMT,shift=True,happsList=labMTvector)
sundayValence,tuesdayFvec = emotion("sunday",labMT,shift=True,happsList=labMTvector)
mondayValence,tuesdayFvec = emotion("monday",labMT,shift=True,happsList=labMTvector)
fridayValence,tuesdayFvec = emotion("friday",labMT,shift=True,happsList=labMTvector)


print(fridayValence)
print(saturdayValence)
print(sundayValence)
print(mondayValence)
# Out:
# 6.88
# 7.42
# 7.28
# 4.3
