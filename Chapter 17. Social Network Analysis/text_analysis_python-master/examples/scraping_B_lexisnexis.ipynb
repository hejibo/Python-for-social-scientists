# %% [markdown]
# # LexisNexis scraper
# Disclaimer: We accept no liability for the content of this code, or for the consequences of any actions taken on the basis of the information provided.
#
# Companies don't like automated methods. The code uses several sleep() functions so it's only a bit faster than doing it by hand. However more reliable and cheaper.
#
# Code from: http://yc-lexisnexis-scraper.readthedocs.org/

# %%
import random
import re
import requests
import urllib.request, urllib.parse, urllib.error
import urllib.parse as urlparse

import selenium.common.exceptions
import selenium.webdriver
import selenium.webdriver.common.desired_capabilities
import selenium.webdriver.support.ui
from selenium.webdriver.support import expected_conditions


class LexisNexisScraper():
    """
    Class for downloading documents given a query string to Lexis Nexis academic (http://www.lexisnexis.com/hottopics/lnacademic/).

    Example::

            downloader = LexisNexisScraper(mass_download_mode=True)
            for (content, (doc_index, doc_count)) in downloader.iter_search_results(6318, 'DATE(=1987)'):
                print doc_id

     """

    _RE_STYLESHEET = re.compile(r'\<STYLE TYPE\=\"text\/css\"\>(\<\!\-\-)?(?P<css_string>.+?)(\-\-\>)?\<\/STYLE\>', flags=re.S | re.U | re.I)
    _RE_LEXIS_DOC = re.compile(r'\<DOC NUMBER\=(?P<docid>\d+)\>\s+\<DOCFULL\>(?P<doc>.+?)\<\/DOCFULL\>', flags=re.S | re.U | re.I)

    def __init__(self, wait_timeouts=(15, 180), documents_per_download=(250, 500), user_agent_string='Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:25.0) Gecko/20100101 Firefox/25.0', mass_download_mode=False):
        """
        Constructs a downloader object.

        :param float,float wait_timeouts: tuple of `(short, long)` where `short` and `long` are the no. of seconds to wait while page elements are loaded (for Webdriver). `long` timeout is used when waiting for LexisNexis to format documents for mass downloads.
        :param int,int documents_per_download: a range specifying the number of documents to download each time when using :attr:`mass_download_mode`.
        :param bool mass_download_mode: whether to mass download articles using the download link or page through each document one by one and download.
        """

        self._USER_AGENT_STRING = user_agent_string
        self._DOCUMENTS_PER_DOWNLOAD = documents_per_download

  
        self._driver = selenium.webdriver.Firefox()
        self._driver.set_window_size(800, 600)

        self._short_wait = selenium.webdriver.support.ui.WebDriverWait(self._driver, wait_timeouts[0], poll_frequency=0.05)
        self._long_wait = selenium.webdriver.support.ui.WebDriverWait(self._driver, wait_timeouts[1], poll_frequency=1)

        self.mass_download_mode_ = mass_download_mode
    #end def

    def __del__(self):
        try: self._driver.quit()
        except: pass

    def iter_search_results(self, csi, search_query, start_from=1):
        """
        A generator function that executes LexisNexis search query on source data CSI (:attr:`csi`), with query :attr:`search_query` and downloads all documents returned by search.

        :param str csi: LexisNexis CSI (see `<http://amdev.net/rpt_download.php>`_ for full list).
        :param str search_query: execute search query string.
        :param int start_from: document index to start downloading from.
        :returns: a tuple `(doc_content, (index, results_count))`, where `doc_content` is the HTML content of the `index`th document, and `results_count` is the number of documents returned by specified search query.
        """

        self._driver.get('http://www.lexisnexis.com/hottopics/lnacademic/?' + urllib.parse.urlencode({'verb': 'sr', 'csi': csi, 'sr': search_query}))
        if not self._have_results(): return []

        if self.mass_download_mode_: return self._mass_download(start_from)
        return self._sequential_download(start_from)
    #end def

    def _have_results(self):    # todo: kinda slow, due to having wait for multiple timeouts
        self._switch_to_frame('main')
        if self._wait_for_element('//td[text()[contains(., \'No Documents Found\')]]', raise_error=False) is not None: return False
        if self._wait_for_element('//frame[@title=\'Results Content Frame\']', raise_error=False) is not None: return True
        if self._wait_for_element('//frame[@title=\'Results Document Content Frame\']', raise_error=False) is not None: return True

        raise Exception('Page loaded improperly while checking for results frame.')
    #end def

    def _mass_download(self, start_from=1):    # Returns documents as a list of strings containing HTML
        self._switch_to_frame('navigation')

        try: documents_count = int(self._driver.find_element_by_xpath('//form[@name=\'results_docview_DocumentForm\']/input[@name=\'totalDocsInResult\']').get_attribute('value'))
        except: documents_count = -1

        def download_sequence(start, end):
            docs_left = end - start + 1
            cur = start
            while docs_left > self._DOCUMENTS_PER_DOWNLOAD[1]:
                download_count = random.randint(*self._DOCUMENTS_PER_DOWNLOAD)
                yield (cur, cur + download_count - 1)
                docs_left -= download_count
                cur += download_count
            #end while

            yield (cur, cur + docs_left - 1)
        #end def

        def lexis_nexis_download_window_appears(current_handle):
            def f(driver):
                for handle in driver.window_handles:
                    if current_handle != handle:
                        driver.switch_to.window(handle)    # switch first to check window title
                        if driver.title.endswith('Download Documents'): return True    # this is our new window!
                    #end if
                #end for

                return False
            #end def

            return f
        #end class

        for download_start, download_end in download_sequence(start_from, documents_count):
            self._switch_to_frame('navigation')

            parent_window_handle = self._driver.current_window_handle

            # check for download icon and click it
            self._wait_for_element('//img[@title=\'Download Documents\']').click()

            # wait for download window to appear
            self._short_wait.until(lexis_nexis_download_window_appears(parent_window_handle))
            self._wait_for_element('//img[@title=\'Download\']')

            # get all the form items
            selenium.webdriver.support.ui.Select(self._driver.find_element_by_xpath('//select[@name=\'delFmt\']')).select_by_value('QDS_EF_HTML')
            selenium.webdriver.support.ui.Select(self._driver.find_element_by_xpath('//select[@name=\'delView\']')).select_by_value('GNBFI')
            selenium.webdriver.support.ui.Select(self._driver.find_element_by_xpath('//select[@name=\'delFontType\']')).select_by_value('COURIER')    # i like courier

            search_term_bold = self._driver.find_element_by_xpath('//input[@type=\'checkbox\'][@id=\'termBold\']')
            if not search_term_bold.is_selected(): search_term_bold.click()
            doc_new_page = self._driver.find_element_by_xpath('//input[@type=\'checkbox\'][@id=\'docnewpg\']')
            if not doc_new_page.is_selected(): doc_new_page.click()

            self._driver.find_element_by_xpath('//input[@type=\'radio\'][@id=\'sel\']').click()
            self._driver.find_element_by_xpath('//input[@type=\'text\'][@id=\'rangetextbox\']').send_keys('{}-{}'.format(download_start, download_end))

            self._driver.find_element_by_xpath('//img[@title=\'Download\']').click()

            download_url = self._long_wait.until(expected_conditions.presence_of_element_located((selenium.webdriver.common.by.By.XPATH, '//center[@class=\'suspendbox\']/p/a'))).get_attribute('href')

            # set up cookies and use requests library to do download
            cookies = dict([(cookie['name'], cookie['value']) for cookie in self._driver.get_cookies()])
            response = requests.get(download_url, cookies=cookies, headers={'User-Agent': self._USER_AGENT_STRING})
            html_content = response.text

            m = self._RE_STYLESHEET.search(html_content)
            css_string = m.group('css_string').strip()

            for i, m in enumerate(self._RE_LEXIS_DOC.finditer(html_content)):
                page_content = m.group('doc').replace('<!-- Hide XML section from browser', '').replace('-->', '').strip()
                page_content = '\n'.join(['<HTML>', '<HEAD>', '<STYLE TYPE=\"text/css\">', css_string, '</STYLE>', '</HEAD>', '<BODY>', page_content, '</BODY>', '</HTML>'])

                yield (page_content, (download_start + i, documents_count))
            #end for

            self._driver.close()
            self._driver.switch_to.window(parent_window_handle)
        #end for
    #end def

    def _sequential_download(self, start_from=1):
        self._switch_to_frame('navigation')
        try: documents_count = int(self._driver.find_element_by_xpath('//form[@name=\'results_docview_DocumentForm\']/input[@name=\'totalDocsInResult\']').get_attribute('value'))
        except: documents_count = -1
        if documents_count <= 0: return

        if start_from > documents_count: return

        if documents_count == 1:
            self._switch_to_frame('content')
            page_content = self._driver.page_source
            yield (page_content, (1, 1))
            return
        #end if

        self._switch_to_frame('results')    # go to results list and grab the first link
        first_document_url = self._wait_for_element('//td/a[contains(@href, \'/lnacui2api/results/docview/docview.do\')]').get_attribute('href')

        url_obj = urlparse.urlparse(first_document_url)
        qs_dict = dict(urlparse.parse_qsl(url_obj.query))
        qs_dict['docNo'] = start_from
        doc_url = urlparse.urlunparse((url_obj.scheme, url_obj.netloc, url_obj.path, url_obj.params, urllib.parse.urlencode(qs_dict), url_obj.fragment))
        self._driver.get(doc_url)    # jump to the page we want

        # qs_dict['RELEVANCE'] = 'BOOLEAN'    # doesnt seem to work
        # http://www.lexisnexis.com/lnacui2api/results/docview/docview.do?docLinkInd=true&risb=21_T21153102977&format=GNBFI&sort=RELEVANCE&startDocNo=1&resultsUrlKey=29_T21153102981&cisb=22_T21153102980&treeMax=true&treeWidth=0&csi=6318&docNo=1

        for doc_index in range(start_from, documents_count + 1):
            self._switch_to_frame('content', in_iframe=False)
            page_content = self._driver.page_source
            yield (page_content, (doc_index, documents_count))

            self._switch_to_frame('navigation', in_iframe=False)
            next_page_elem = self._wait_for_element('//img[@title=\'View next document\']', raise_error=False)
            if next_page_elem is None:
                if doc_index != documents_count:
                    raise Exception('Next page icon could not be found: doc_index={}, documents_count={}'.format(doc_index, documents_count))
            else: next_page_elem.click()
        #end while
    #end def

    def _switch_to_frame(self, frame_name, in_iframe=True):
        self._driver.switch_to.default_content()

        if in_iframe:
            frame = self._safe_wait(expected_conditions.frame_to_be_available_and_switch_to_it('mainFrame'))
            if not frame: raise SwitchFrameException(frame_name)
        #end if

        try:
            if frame_name == 'main': return frame
            elif frame_name == 'results': frame = self._wait_for_element('//frame[@title=\'Results Content Frame\']')
            elif frame_name == 'navigation': frame = self._wait_for_element('//frame[@title=\'Results Navigation Frame\']')
            elif frame_name == 'content': frame = self._wait_for_element('//frame[@title=\'Results Document Content Frame\']')
        except selenium.common.exceptions.TimeoutException:
            raise SwitchFrameException(frame_name)

        self._safe_wait(expected_conditions.frame_to_be_available_and_switch_to_it(frame))

        return frame
    #end def

    def _safe_wait(self, poll_func):
        try: return self._short_wait.until(poll_func)
        except selenium.common.exceptions.TimeoutException: return None
    #end def

    def _wait_for_element(self, xpath, raise_error=True):
        elem = self._safe_wait(expected_conditions.presence_of_element_located((selenium.webdriver.common.by.By.XPATH, xpath)))
        if raise_error and elem is None: raise selenium.common.exceptions.TimeoutException(msg='XPath \'{}\' presence wait timeout.'.format(xpath))
        return elem
    #end def
#end class


class SwitchFrameException(Exception):
    """
    Exception class when we are unable to load the require page properly.
    This is usually due to
    #. Page taking too long to load. This happens sometimes when loading LexisNexis for the first time.
    #. Improper page loading.
    """

    def __init__(self, frame_name): self.frame_name = frame_name

    def __str__(self): return 'Exception while switching to frame \'{}\'.'.format(self.frame_name)
#end class

# %%
import bs4 as bs
def scrape_news(csi,init_date,end_date,search,path="./"):
    """
    call the code from that other person, saves the results (one file = one article)
    """
    import os      
    os.makedirs(os.path.dirname(path), exist_ok=True)
    query = "{0} AND Date(geq({1}) AND leq({2}))".format(search,init_date,end_date)

    scraper = LexisNexisScraper(mass_download_mode=True)

    for (content, (doc_index, doc_count)) in scraper.iter_search_results(csi,query):
        with open("{0}/{1}_{2}_{3}.csv".format(path,search.replace(" ","_").replace("/","-"),doc_index, doc_count), "w+") as fOut:
            fOut.write(content)    


def format_new(content):
    """
    finds the article as a paragraph with class c8 or c9, and the other parts that we want too
    """
    html = bs.BeautifulSoup(content, "lxml")
    #print(html.prettify())
    new = " ".join([_.text for _ in html.find_all("p",{"class": ["c8","c9"]}) if len(_.text) > 100])
    other_parts = html.find_all("p",{"class": "c1"})
    date = other_parts[2].text
    newspaper = other_parts[1].text
    print(date)
    return date,newspaper,new

def format_all_files(path,file_out_name,search):
    """
    format the files, saving date, newspaper and article and saves the result
    """
    import os      
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open("./data/{0}".format(file_out_name),"w+") as fOut:        
        for file in sorted(os.listdir(path)):
            if not search.replace(" ","_") in file: continue
            print(file)
            date,newspaper,new = format_new(open("./data/news_raw/{0}".format(file)))    
            if len(new) > 100:
                fOut.write("{0}\t{1}\t{2}\n".format(date,newspaper,new))
            #break

# %%
def podemos():
    csi = "166103"

    init_date = "11/20/2015" #format: mm/dd/yyyy
    end_date = "1/20/2016"  #format: mm/dd/yyyy

    search = "Pablo Iglesias AND Podemos"
    scrape_news(csi,init_date,end_date,search,path="./data/news_raw")


    path = "./data/news_raw/"
    file_out_name = "Pablo_Iglesias_Podemos.csv"
    format_all_files(path,file_out_name,search)

def ciudadanos():
    csi = "166103"

    init_date = "11/20/2015" #format: mm/dd/yyyy
    end_date = "1/20/2016"  #format: mm/dd/yyyy

    search = "Albert Rivera AND Ciudadanos"
    scrape_news(csi,init_date,end_date,search,path="./data/news_raw")


    path = "./data/news_raw/"
    file_out_name = "Albert_Rivera_Ciudadanos.csv"
    format_all_files(path,file_out_name,search)

def psoe():
    csi = "166103"

    init_date = "11/20/2015" #format: mm/dd/yyyy
    end_date = "1/20/2016"  #format: mm/dd/yyyy

    search = "Pedro Sanchez AND PSOE"
    scrape_news(csi,init_date,end_date,search,path="./data/news_raw")


    path = "./data/news_raw/"
    file_out_name = "Pedro_Sanchez_PSOE.csv"
    format_all_files(path,file_out_name,search)

def pp():
    csi = "166103"

    init_date = "11/20/2015" #format: mm/dd/yyyy
    end_date = "1/20/2016"  #format: mm/dd/yyyy

    search = "Mariano Rajoy AND PP"
    scrape_news(csi,init_date,end_date,search,path="./data/news_raw")


    path = "./data/news_raw/"
    file_out_name = "Mariano_Rajoy_PP.csv"
    format_all_files(path,file_out_name,search)

    
psoe()
pp()
# Out:
# Pedro_Sanchez_AND_PSOE_1000_1152.csv
# December 5, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1001_1152.csv
# December 6, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1002_1152.csv
# December 6, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1003_1152.csv
# December 6, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1004_1152.csv
# December 6, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1005_1152.csv
# December 7, 2015 Monday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1006_1152.csv
# December 7, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1007_1152.csv
# December 7, 2015 Monday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1008_1152.csv
# December 7, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1009_1152.csv
# December 8, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_100_1152.csv
# January 12, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1010_1152.csv
# December 8, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1011_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1012_1152.csv
# December 9, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1013_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1014_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1015_1152.csv
# December 9, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1016_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1017_1152.csv
# December 10, 2015 Thursday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1018_1152.csv
# December 10, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1019_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_101_1152.csv
# January 12, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1020_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1021_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1022_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1023_1152.csv
# December 10, 2015 Thursday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1024_1152.csv
# December 10, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1025_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1026_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1027_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1028_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1029_1152.csv
# December 11, 2015 Friday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_102_1152.csv
# December 24, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1030_1152.csv
# December 11, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1031_1152.csv
# December 11, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1032_1152.csv
# December 11, 2015 Friday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1033_1152.csv
# December 11, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1034_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1035_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1036_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1037_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1038_1152.csv
# December 11, 2015 Friday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1039_1152.csv
# December 11, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_103_1152.csv
# December 24, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1040_1152.csv
# December 11, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1041_1152.csv
# December 11, 2015 Friday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1042_1152.csv
# December 11, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1043_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1044_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1045_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1046_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1047_1152.csv
# December 12, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1048_1152.csv
# December 12, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1049_1152.csv
# December 12, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_104_1152.csv
# December 24, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1050_1152.csv
# December 12, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1051_1152.csv
# December 12, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1052_1152.csv
# December 12, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1053_1152.csv
# December 13, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1054_1152.csv
# December 13, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1055_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1056_1152.csv
# December 14, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1057_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1058_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1059_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_105_1152.csv
# December 24, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1060_1152.csv
# December 14, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1061_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1062_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1063_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1064_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1065_1152.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1066_1152.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1067_1152.csv
# December 16, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1068_1152.csv
# December 16, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1069_1152.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_106_1152.csv
# December 28, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1070_1152.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1071_1152.csv
# December 16, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1072_1152.csv
# December 16, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1073_1152.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1074_1152.csv
# December 17, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1075_1152.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1076_1152.csv
# December 17, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1077_1152.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1078_1152.csv
# December 17, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1079_1152.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_107_1152.csv
# December 28, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1080_1152.csv
# December 17, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1081_1152.csv
# December 19, 2015 Saturday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1082_1152.csv
# December 19, 2015 Saturday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1083_1152.csv
# December 19, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1084_1152.csv
# December 19, 2015 Saturday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1085_1152.csv
# December 19, 2015 Saturday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1086_1152.csv
# December 19, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1087_1152.csv
# December 20, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1088_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1089_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_108_1152.csv
# December 7, 2015 Monday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1090_1152.csv
# December 20, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1091_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1092_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1093_1152.csv
# December 21, 2015 Monday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1094_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1095_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1096_1152.csv
# December 21, 2015 Monday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1097_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1098_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1099_1152.csv
# December 22, 2015 Tuesday  1ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_109_1152.csv
# December 7, 2015 Monday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_10_1152.csv
# December 29, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1100_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1101_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1102_1152.csv
# December 22, 2015 Tuesday  1ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1103_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1104_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1105_1152.csv
# December 23, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1106_1152.csv
# December 23, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1107_1152.csv
# December 23, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1108_1152.csv
# December 23, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1109_1152.csv
# December 23, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_110_1152.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1110_1152.csv
# December 23, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1111_1152.csv
# December 23, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1112_1152.csv
# December 23, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1113_1152.csv
# December 24, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1114_1152.csv
# December 24, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1115_1152.csv
# December 28, 2015 Monday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1116_1152.csv
# December 28, 2015 Monday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1117_1152.csv
# December 30, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1118_1152.csv
# December 30, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_1119_1152.csv
# January 5, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_111_1152.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1120_1152.csv
# January 5, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1121_1152.csv
# January 6, 2016 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1122_1152.csv
# January 6, 2016 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1123_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1124_1152.csv
# January 7, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1125_1152.csv
# January 7, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1126_1152.csv
# January 7, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1127_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1128_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1129_1152.csv
# January 7, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_112_1152.csv
# December 17, 2015 Thursday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1130_1152.csv
# January 7, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1131_1152.csv
# January 7, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1132_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1133_1152.csv
# January 8, 2016 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1134_1152.csv
# January 8, 2016 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1135_1152.csv
# January 8, 2016 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1136_1152.csv
# January 8, 2016 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1137_1152.csv
# January 11, 2016 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1138_1152.csv
# January 11, 2016 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1139_1152.csv
# January 12, 2016 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_113_1152.csv
# December 17, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1140_1152.csv
# January 12, 2016 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1141_1152.csv
# January 12, 2016 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_1142_1152.csv
# January 12, 2016 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1143_1152.csv
# January 13, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1144_1152.csv
# January 13, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1145_1152.csv
# January 14, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1146_1152.csv
# January 14, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1147_1152.csv
# January 14, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1148_1152.csv
# January 14, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_1149_1152.csv
# January 16, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_114_1152.csv
# December 17, 2015 Thursday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1150_1152.csv
# January 16, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1151_1152.csv
# January 18, 2016 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_1152_1152.csv
# January 19, 2016 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_115_1152.csv
# December 17, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_116_1152.csv
# January 13, 2016 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_117_1152.csv
# January 13, 2016 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_118_1152.csv
# January 13, 2016 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_119_1152.csv
# January 13, 2016 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_11_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_120_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_121_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_122_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_123_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_124_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_125_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_126_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_127_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_128_1152.csv
# December 16, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_129_1152.csv
# December 16, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_12_1152.csv
# December 29, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_130_1152.csv
# December 23, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_131_1152.csv
# December 23, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_132_1152.csv
# January 15, 2016 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_133_1152.csv
# January 15, 2016 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_134_1152.csv
# December 31, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_135_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_136_1152.csv
# December 31, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_137_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_138_1152.csv
# January 19, 2016 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_139_1152.csv
# January 19, 2016 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_13_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_140_1152.csv
# December 5, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_141_1152.csv
# December 5, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_142_1152.csv
# December 5, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_143_1152.csv
# December 5, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_144_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_145_1152.csv
# December 14, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_146_1152.csv
# December 16, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_147_1152.csv
# December 16, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_148_1152.csv
# December 17, 2015 Thursday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_149_1152.csv
# December 17, 2015 Thursday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_14_1152.csv
# December 24, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_150_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_151_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_152_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_153_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_154_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_155_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_156_1152.csv
# November 25, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_157_1152.csv
# November 25, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_158_1152.csv
# December 13, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_159_1152.csv
# December 13, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_15_1152.csv
# December 24, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_160_1152.csv
# December 14, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_161_1152.csv
# December 14, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_162_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_163_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_164_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_165_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_166_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_167_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_168_1152.csv
# December 29, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_169_1152.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_16_1152.csv
# January 6, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_170_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_171_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_172_1152.csv
# December 29, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_173_1152.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_174_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_175_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_176_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_177_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_178_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_179_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_17_1152.csv
# January 6, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_180_1152.csv
# December 27, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_181_1152.csv
# December 27, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_182_1152.csv
# November 25, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_183_1152.csv
# November 25, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_184_1152.csv
# November 29, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_185_1152.csv
# November 29, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_186_1152.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_187_1152.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_188_1152.csv
# December 6, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_189_1152.csv
# December 6, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_18_1152.csv
# January 14, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_190_1152.csv
# December 7, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_191_1152.csv
# December 7, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_192_1152.csv
# December 10, 2015 Thursday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_193_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_194_1152.csv
# December 10, 2015 Thursday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_195_1152.csv
# December 10, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_196_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_197_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_198_1152.csv
# January 13, 2016 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_199_1152.csv
# January 13, 2016 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_19_1152.csv
# January 14, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_1_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_200_1152.csv
# January 15, 2016 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_201_1152.csv
# January 15, 2016 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_202_1152.csv
# January 15, 2016 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_203_1152.csv
# January 15, 2016 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_204_1152.csv
# November 23, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_205_1152.csv
# November 23, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_206_1152.csv
# December 8, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_207_1152.csv
# December 8, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_208_1152.csv
# November 25, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_209_1152.csv
# November 25, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_20_1152.csv
# January 14, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_210_1152.csv
# November 25, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_211_1152.csv
# November 25, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_212_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_213_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_214_1152.csv
# December 4, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_215_1152.csv
# December 4, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_216_1152.csv
# December 4, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_217_1152.csv
# December 4, 2015 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_218_1152.csv
# December 4, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_219_1152.csv
# December 4, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_21_1152.csv
# January 14, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_220_1152.csv
# December 4, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_221_1152.csv
# December 4, 2015 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_222_1152.csv
# December 7, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_223_1152.csv
# December 7, 2015 Monday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_224_1152.csv
# December 7, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_225_1152.csv
# December 7, 2015 Monday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_226_1152.csv
# December 30, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_227_1152.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_228_1152.csv
# December 30, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_229_1152.csv
# December 30, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_22_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_230_1152.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_231_1152.csv
# December 30, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_232_1152.csv
# December 31, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_233_1152.csv
# December 31, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_234_1152.csv
# January 9, 2016 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_235_1152.csv
# January 9, 2016 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_236_1152.csv
# January 14, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_237_1152.csv
# January 14, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_238_1152.csv
# January 14, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_239_1152.csv
# January 14, 2016 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_23_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_240_1152.csv
# January 16, 2016 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_241_1152.csv
# January 16, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_242_1152.csv
# January 16, 2016 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_243_1152.csv
# January 16, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_244_1152.csv
# January 17, 2016 Sunday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_245_1152.csv
# January 17, 2016 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_246_1152.csv
# January 17, 2016 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_247_1152.csv
# January 17, 2016 Sunday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_248_1152.csv
# January 17, 2016 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_249_1152.csv
# January 17, 2016 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_24_1152.csv
# December 26, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_250_1152.csv
# January 18, 2016 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_251_1152.csv
# January 20, 2016 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_252_1152.csv
# January 20, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_253_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_254_1152.csv
# December 1, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_255_1152.csv
# December 1, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_256_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_257_1152.csv
# December 1, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_258_1152.csv
# December 1, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_259_1152.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_25_1152.csv
# December 26, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_260_1152.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_261_1152.csv
# December 8, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_262_1152.csv
# December 8, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_263_1152.csv
# December 8, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_264_1152.csv
# December 8, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_265_1152.csv
# December 11, 2015 Friday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_266_1152.csv
# December 11, 2015 Friday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_267_1152.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_268_1152.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_269_1152.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_26_1152.csv
# January 3, 2016 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_270_1152.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_271_1152.csv
# January 2, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_272_1152.csv
# January 2, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_273_1152.csv
# January 9, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_274_1152.csv
# January 9, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_275_1152.csv
# January 13, 2016 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_276_1152.csv
# January 13, 2016 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_277_1152.csv
# January 16, 2016 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_278_1152.csv
# January 16, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_279_1152.csv
# January 16, 2016 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_27_1152.csv
# January 3, 2016 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_280_1152.csv
# January 16, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_281_1152.csv
# January 17, 2016 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_282_1152.csv
# January 17, 2016 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_283_1152.csv
# December 4, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_284_1152.csv
# December 4, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_285_1152.csv
# December 4, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_286_1152.csv
# December 4, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_287_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_288_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_289_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_28_1152.csv
# December 13, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_290_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_291_1152.csv
# December 26, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_292_1152.csv
# December 26, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_293_1152.csv
# January 8, 2016 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_294_1152.csv
# January 8, 2016 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_295_1152.csv
# December 1, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_296_1152.csv
# December 1, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_297_1152.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_298_1152.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_299_1152.csv
# December 4, 2015 Friday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_29_1152.csv
# December 13, 2015 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_2_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_300_1152.csv
# December 4, 2015 Friday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_301_1152.csv
# December 12, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_302_1152.csv
# December 12, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_303_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_304_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_305_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_306_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_307_1152.csv
# December 23, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_308_1152.csv
# December 23, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_309_1152.csv
# December 23, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_30_1152.csv
# January 5, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_310_1152.csv
# December 23, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_311_1152.csv
# January 9, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_312_1152.csv
# January 9, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_313_1152.csv
# January 13, 2016 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_314_1152.csv
# January 13, 2016 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_315_1152.csv
# January 13, 2016 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_316_1152.csv
# January 13, 2016 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_317_1152.csv
# January 19, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_318_1152.csv
# November 21, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_319_1152.csv
# November 21, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_31_1152.csv
# January 5, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_320_1152.csv
# November 21, 2015 Saturday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_321_1152.csv
# November 21, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_322_1152.csv
# December 4, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_323_1152.csv
# December 4, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_324_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_325_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_326_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_327_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_328_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_329_1152.csv
# December 10, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_32_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_330_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_331_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_332_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_333_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_334_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_335_1152.csv
# December 22, 2015 Tuesday  1ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_336_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_337_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_338_1152.csv
# December 22, 2015 Tuesday  1ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_339_1152.csv
# December 22, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_33_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_340_1152.csv
# December 23, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_341_1152.csv
# December 23, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_342_1152.csv
# December 26, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_343_1152.csv
# December 26, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_344_1152.csv
# December 28, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_345_1152.csv
# December 28, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_346_1152.csv
# December 28, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_347_1152.csv
# December 28, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_348_1152.csv
# January 9, 2016 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_349_1152.csv
# January 9, 2016 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_34_1152.csv
# December 26, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_350_1152.csv
# January 12, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_351_1152.csv
# January 12, 2016 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_352_1152.csv
# January 12, 2016 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_353_1152.csv
# January 12, 2016 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_354_1152.csv
# January 17, 2016 Sunday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_355_1152.csv
# January 17, 2016 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_356_1152.csv
# January 17, 2016 Sunday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_357_1152.csv
# January 17, 2016 Sunday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_358_1152.csv
# January 18, 2016 Monday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_359_1152.csv
# January 18, 2016 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_35_1152.csv
# December 26, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_360_1152.csv
# January 19, 2016 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_361_1152.csv
# November 26, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_362_1152.csv
# November 26, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_363_1152.csv
# November 26, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_364_1152.csv
# November 26, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_365_1152.csv
# December 11, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_366_1152.csv
# December 11, 2015 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_367_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_368_1152.csv
# December 11, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_369_1152.csv
# December 11, 2015 Friday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_36_1152.csv
# December 28, 2015 Monday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_370_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_371_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_372_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_373_1152.csv
# December 24, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_374_1152.csv
# December 24, 2015 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_375_1152.csv
# November 27, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_376_1152.csv
# November 27, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_377_1152.csv
# November 27, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_378_1152.csv
# November 27, 2015 Friday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_379_1152.csv
# November 27, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_37_1152.csv
# December 28, 2015 Monday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_380_1152.csv
# November 27, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_381_1152.csv
# December 7, 2015 Monday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_382_1152.csv
# December 7, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_383_1152.csv
# December 7, 2015 Monday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_384_1152.csv
# December 7, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_385_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_386_1152.csv
# December 11, 2015 Friday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_387_1152.csv
# December 14, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_388_1152.csv
# December 14, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_389_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_38_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_390_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_391_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_392_1152.csv
# December 22, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_393_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_394_1152.csv
# December 22, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_395_1152.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_396_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_397_1152.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_398_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_399_1152.csv
# January 20, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_39_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_3_1152.csv
# December 21, 2015 Monday  1ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_400_1152.csv
# November 25, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_401_1152.csv
# November 25, 2015 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_402_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_403_1152.csv
# December 1, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_404_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_405_1152.csv
# December 1, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_406_1152.csv
# December 4, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_407_1152.csv
# December 4, 2015 Friday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_408_1152.csv
# December 9, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_409_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_40_1152.csv
# November 22, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_410_1152.csv
# December 9, 2015 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_411_1152.csv
# December 9, 2015 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_412_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_413_1152.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_414_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_415_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_416_1152.csv
# December 19, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_417_1152.csv
# December 19, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_418_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_419_1152.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_41_1152.csv
# November 22, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_420_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_421_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_422_1152.csv
# December 21, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_423_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_424_1152.csv
# December 21, 2015 Monday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_425_1152.csv
# December 21, 2015 Monday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_426_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_427_1152.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_428_1152.csv
# December 24, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_429_1152.csv
# December 24, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_42_1152.csv
# December 6, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_430_1152.csv
# December 24, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_431_1152.csv
# December 24, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_432_1152.csv
# December 29, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_433_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_434_1152.csv
# December 29, 2015 Tuesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_435_1152.csv
# December 29, 2015 Tuesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_436_1152.csv
# December 31, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_437_1152.csv
# December 31, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_438_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_439_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_43_1152.csv
# December 6, 2015 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_440_1152.csv
# December 31, 2015 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_441_1152.csv
# December 31, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_442_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_443_1152.csv
# December 31, 2015 Thursday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_444_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_445_1152.csv
# January 7, 2016 Thursday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_446_1152.csv
# January 10, 2016 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_447_1152.csv
# January 10, 2016 Sunday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_448_1152.csv
# January 13, 2016 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_449_1152.csv
# January 13, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_44_1152.csv
# January 9, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_450_1152.csv
# January 13, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_451_1152.csv
# January 13, 2016 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_452_1152.csv
# January 13, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_453_1152.csv
# January 13, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_454_1152.csv
# January 14, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_455_1152.csv
# January 14, 2016 Thursday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_456_1152.csv
# January 18, 2016 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_457_1152.csv
# January 18, 2016 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_458_1152.csv
# January 20, 2016 Wednesday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_459_1152.csv
# January 20, 2016 Wednesday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_45_1152.csv
# January 9, 2016 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_460_1152.csv
# January 20, 2016 Wednesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_461_1152.csv
# November 30, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_462_1152.csv
# November 30, 2015 Monday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_463_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_464_1152.csv
# December 9, 2015 Wednesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_465_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_466_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_467_1152.csv
# December 1, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_468_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Madrid Edición
# Pedro_Sanchez_AND_PSOE_469_1152.csv
# December 1, 2015 Tuesday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_46_1152.csv
# December 19, 2015 Saturday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_470_1152.csv
# December 1, 2015 Tuesday  Comunidad Valenciana Edición
# Pedro_Sanchez_AND_PSOE_471_1152.csv
# December 5, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_472_1152.csv
# December 5, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_473_1152.csv
# December 5, 2015 Saturday  Andalucía Edición
# Pedro_Sanchez_AND_PSOE_474_1152.csv
# December 5, 2015 Saturday  Nacional Edición
# Pedro_Sanchez_AND_PSOE_475_1152.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_476_1152.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_477_1152.csv
# December 19, 2015 Saturday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_478_1152.csv
# December 19, 2015 Saturday  1ª Ed. Barna Edición
# Pedro_Sanchez_AND_PSOE_479_1152.csv
# ...
# December 1, 2015 Tuesday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_761_931.csv
# December 1, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_762_931.csv
# December 1, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_763_931.csv
# December 1, 2015 Tuesday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_764_931.csv
# December 2, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_765_931.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_766_931.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_767_931.csv
# December 2, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_768_931.csv
# December 2, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_769_931.csv
# December 2, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_76_931.csv
# January 7, 2016 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_770_931.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_771_931.csv
# December 2, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_772_931.csv
# December 2, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_773_931.csv
# December 2, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_774_931.csv
# December 3, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_775_931.csv
# December 3, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_776_931.csv
# December 4, 2015 Friday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_777_931.csv
# December 4, 2015 Friday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_778_931.csv
# December 4, 2015 Friday  Andalucía Edición
# Mariano_Rajoy_AND_PP_779_931.csv
# December 4, 2015 Friday  Nacional Edición
# Mariano_Rajoy_AND_PP_77_931.csv
# January 17, 2016 Sunday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_780_931.csv
# December 4, 2015 Friday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_781_931.csv
# December 4, 2015 Friday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_782_931.csv
# December 4, 2015 Friday  Andalucía Edición
# Mariano_Rajoy_AND_PP_783_931.csv
# December 4, 2015 Friday  Nacional Edición
# Mariano_Rajoy_AND_PP_784_931.csv
# December 5, 2015 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_785_931.csv
# December 5, 2015 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_786_931.csv
# December 6, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_787_931.csv
# December 6, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_788_931.csv
# December 6, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_789_931.csv
# December 6, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_78_931.csv
# January 17, 2016 Sunday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_790_931.csv
# December 7, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_791_931.csv
# December 7, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_792_931.csv
# December 7, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_793_931.csv
# December 7, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_794_931.csv
# December 8, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_795_931.csv
# December 8, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_796_931.csv
# December 9, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_797_931.csv
# December 9, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_798_931.csv
# December 9, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_799_931.csv
# December 9, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_79_931.csv
# December 23, 2015 Wednesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_7_931.csv
# December 15, 2015 Tuesday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_800_931.csv
# December 9, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_801_931.csv
# December 9, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_802_931.csv
# December 10, 2015 Thursday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_803_931.csv
# December 10, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_804_931.csv
# December 10, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_805_931.csv
# December 10, 2015 Thursday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_806_931.csv
# December 10, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_807_931.csv
# December 10, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_808_931.csv
# December 12, 2015 Saturday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_809_931.csv
# December 12, 2015 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_80_931.csv
# December 23, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_810_931.csv
# December 12, 2015 Saturday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_811_931.csv
# December 12, 2015 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_812_931.csv
# December 12, 2015 Saturday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_813_931.csv
# December 12, 2015 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_814_931.csv
# December 12, 2015 Saturday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_815_931.csv
# December 12, 2015 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_816_931.csv
# December 13, 2015 Sunday  Andalucía Edición
# Mariano_Rajoy_AND_PP_817_931.csv
# December 13, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_818_931.csv
# December 13, 2015 Sunday  Andalucía Edición
# Mariano_Rajoy_AND_PP_819_931.csv
# December 13, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_81_931.csv
# December 23, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_820_931.csv
# December 14, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_821_931.csv
# December 14, 2015 Monday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_822_931.csv
# December 14, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_823_931.csv
# December 14, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_824_931.csv
# December 14, 2015 Monday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_825_931.csv
# December 14, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_826_931.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_827_931.csv
# December 15, 2015 Tuesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_828_931.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_829_931.csv
# December 16, 2015 Wednesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_82_931.csv
# December 23, 2015 Wednesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_830_931.csv
# December 16, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_831_931.csv
# December 16, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_832_931.csv
# December 16, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_833_931.csv
# December 16, 2015 Wednesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_834_931.csv
# December 16, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_835_931.csv
# December 16, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_836_931.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_837_931.csv
# December 17, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_838_931.csv
# December 17, 2015 Thursday  Andalucía Edición
# Mariano_Rajoy_AND_PP_839_931.csv
# December 17, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_83_931.csv
# December 23, 2015 Wednesday  Andalucía Edición
# Mariano_Rajoy_AND_PP_840_931.csv
# December 17, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_841_931.csv
# December 17, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_842_931.csv
# December 17, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_843_931.csv
# December 17, 2015 Thursday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_844_931.csv
# December 17, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_845_931.csv
# December 17, 2015 Thursday  Andalucía Edición
# Mariano_Rajoy_AND_PP_846_931.csv
# December 17, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_847_931.csv
# December 17, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_848_931.csv
# December 17, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_849_931.csv
# December 17, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_84_931.csv
# December 23, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_850_931.csv
# December 19, 2015 Saturday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_851_931.csv
# December 19, 2015 Saturday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_852_931.csv
# December 19, 2015 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_853_931.csv
# December 19, 2015 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_854_931.csv
# December 19, 2015 Saturday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_855_931.csv
# December 19, 2015 Saturday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_856_931.csv
# December 19, 2015 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_857_931.csv
# December 19, 2015 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_858_931.csv
# December 20, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_859_931.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_85_931.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_860_931.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_861_931.csv
# December 20, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_862_931.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_863_931.csv
# December 20, 2015 Sunday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_864_931.csv
# December 21, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_865_931.csv
# December 21, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_866_931.csv
# December 21, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_867_931.csv
# December 21, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_868_931.csv
# December 21, 2015 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_869_931.csv
# December 21, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_86_931.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_870_931.csv
# December 24, 2015 Thursday  Andalucía Edición
# Mariano_Rajoy_AND_PP_871_931.csv
# December 24, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_872_931.csv
# December 24, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_873_931.csv
# December 24, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_874_931.csv
# December 24, 2015 Thursday  Andalucía Edición
# Mariano_Rajoy_AND_PP_875_931.csv
# December 24, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_876_931.csv
# December 24, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_877_931.csv
# December 24, 2015 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_878_931.csv
# December 26, 2015 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_879_931.csv
# December 26, 2015 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_87_931.csv
# January 14, 2016 Thursday  Andalucía Edición
# Mariano_Rajoy_AND_PP_880_931.csv
# December 27, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_881_931.csv
# December 27, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_882_931.csv
# December 27, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_883_931.csv
# December 27, 2015 Sunday  Nacional Edición
# Mariano_Rajoy_AND_PP_884_931.csv
# December 28, 2015 Monday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_885_931.csv
# December 28, 2015 Monday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_886_931.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_887_931.csv
# December 29, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_888_931.csv
# December 29, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_889_931.csv
# December 29, 2015 Tuesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_88_931.csv
# January 14, 2016 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_890_931.csv
# December 29, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_891_931.csv
# December 29, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_892_931.csv
# December 30, 2015 Wednesday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_893_931.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_894_931.csv
# December 30, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_895_931.csv
# December 30, 2015 Wednesday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_896_931.csv
# December 30, 2015 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_897_931.csv
# December 30, 2015 Wednesday  Nacional Edición
# Mariano_Rajoy_AND_PP_898_931.csv
# December 31, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_899_931.csv
# December 31, 2015 Thursday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_89_931.csv
# January 14, 2016 Thursday  Andalucía Edición
# Mariano_Rajoy_AND_PP_8_931.csv
# December 15, 2015 Tuesday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_900_931.csv
# January 2, 2016 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_901_931.csv
# January 2, 2016 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_902_931.csv
# January 2, 2016 Saturday  Andalucía Edición
# Mariano_Rajoy_AND_PP_903_931.csv
# January 2, 2016 Saturday  Nacional Edición
# Mariano_Rajoy_AND_PP_904_931.csv
# January 3, 2016 Sunday  Andalucía Edición
# Mariano_Rajoy_AND_PP_905_931.csv
# January 3, 2016 Sunday  Andalucía Edición
# Mariano_Rajoy_AND_PP_906_931.csv
# January 4, 2016 Monday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_907_931.csv
# January 4, 2016 Monday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_908_931.csv
# January 6, 2016 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_909_931.csv
# January 6, 2016 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_90_931.csv
# January 14, 2016 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_910_931.csv
# January 6, 2016 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_911_931.csv
# January 6, 2016 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_912_931.csv
# January 10, 2016 Sunday  Andalucía Edición
# Mariano_Rajoy_AND_PP_913_931.csv
# January 10, 2016 Sunday  Andalucía Edición
# Mariano_Rajoy_AND_PP_914_931.csv
# January 13, 2016 Wednesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_915_931.csv
# January 13, 2016 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_916_931.csv
# January 13, 2016 Wednesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_917_931.csv
# January 13, 2016 Wednesday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_918_931.csv
# January 14, 2016 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_919_931.csv
# January 14, 2016 Thursday  Nacional Edición
# Mariano_Rajoy_AND_PP_91_931.csv
# January 19, 2016 Tuesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_920_931.csv
# January 15, 2016 Friday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_921_931.csv
# January 15, 2016 Friday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_922_931.csv
# January 15, 2016 Friday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_923_931.csv
# January 15, 2016 Friday  Andalucía Edición
# Mariano_Rajoy_AND_PP_924_931.csv
# January 15, 2016 Friday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_925_931.csv
# January 15, 2016 Friday  2ª Ed. Madrid Edición
# Mariano_Rajoy_AND_PP_926_931.csv
# January 15, 2016 Friday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_927_931.csv
# January 15, 2016 Friday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_928_931.csv
# January 15, 2016 Friday  Andalucía Edición
# Mariano_Rajoy_AND_PP_929_931.csv
# January 15, 2016 Friday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_92_931.csv
# December 21, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_930_931.csv
# January 18, 2016 Monday  Nacional Edición
# Mariano_Rajoy_AND_PP_931_931.csv
# January 19, 2016 Tuesday  1ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_93_931.csv
# December 21, 2015 Monday  Andalucía Edición
# Mariano_Rajoy_AND_PP_94_931.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_95_931.csv
# December 22, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_96_931.csv
# December 22, 2015 Tuesday  2ª Ed. Barna Edición
# Mariano_Rajoy_AND_PP_97_931.csv
# December 22, 2015 Tuesday  Nacional Edición
# Mariano_Rajoy_AND_PP_98_931.csv
# November 30, 2015 Monday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_99_931.csv
# November 30, 2015 Monday  Comunidad Valenciana Edición
# Mariano_Rajoy_AND_PP_9_931.csv
# December 5, 2015 Saturday  Andalucía Edición

# %%
csi = "166103"
path = "./data/news_raw/"

for month in range(1,12):
    init_date = "{0}/20/2015".format(month) #format: mm/dd/yyyy
    end_date = "{0}+1/20/2015".format(month)  #format: mm/dd/yyyy

    search = "Pedro Sanchez AND PSOE"
    scrape_news(csi,init_date,end_date,search,path=path)


file_out_name = "Pedro_Sanchez_PSOE.csv"
format_all_files(path,file_out_name,search)
